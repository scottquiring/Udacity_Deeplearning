# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
np.random.random()

from collections import Counter

# %%
word_counts = Counter(int_words)

# %%
threshold = 1e-5

def word_frequency(word):
    return word_counts[word] / len(int_words)

def word_probability(word, threshold):
    return 1.0 - np.sqrt(threshold / word_frequency(word))

word_probabilities = {w: word_probability(w, threshold) for w in int_to_vocab.keys()}

# %%
train_words = [w for w in int_words if word_probabilities[w] < np.random.random()]

# %%
word_probabilities[vocab_to_int['hero']]
# Out:
# 0.52996267585146473

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = np.random.randint(1,window_size+1)
    minIdx = max(idx-r,0)
    maxIdx = min(idx+r+1,len(words))
    return words[minIdx:idx] + words[idx+1:maxIdx]

# %%
train_words[4627032:4627031]
#len(train_words)
# Out:
# []

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding), -1,1))
    embed = tf.nn.embedding_lookup(embedding, inputs)
    # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b,
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']
# Out:
# '0'

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 12
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    log += ', '.join([int_to_vocab[nearest[k]] for k in range(top_k)])
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/12 Iteration: 100 Avg. Training loss: 5.5876 0.0516 sec/batch
# Epoch 1/12 Iteration: 200 Avg. Training loss: 5.5747 0.0479 sec/batch
# Epoch 1/12 Iteration: 300 Avg. Training loss: 5.5090 0.0481 sec/batch
# Epoch 1/12 Iteration: 400 Avg. Training loss: 5.5564 0.0478 sec/batch
# Epoch 1/12 Iteration: 500 Avg. Training loss: 5.4641 0.0479 sec/batch
# Epoch 1/12 Iteration: 600 Avg. Training loss: 5.4264 0.0478 sec/batch
# Epoch 1/12 Iteration: 700 Avg. Training loss: 5.5138 0.0481 sec/batch
# Epoch 1/12 Iteration: 800 Avg. Training loss: 5.5249 0.0476 sec/batch
# Epoch 1/12 Iteration: 900 Avg. Training loss: 5.4246 0.0479 sec/batch
# Epoch 1/12 Iteration: 1000 Avg. Training loss: 5.3566 0.0476 sec/batch
# Nearest to between:appropriation, intimate, pentium, surround, levitical, anabaptism, spontaneous, nubia
# Nearest to however:michele, eleusis, giraud, reviewers, hanover, weems, yun, sandawe
# Nearest to eight:yoruba, lynch, kelly, dials, vitro, dewan, overbending, vida
# Nearest to history:whipple, amsterdam, darwinism, kessler, yalta, alces, adel, firearm
# Nearest to in:lysis, conducted, keita, methodical, cartoon, metres, maxim, crush
# Nearest to who:enough, nevers, manslaughter, retained, aguilera, lesotho, trinkets, faraway
# Nearest to two:agha, side, beech, punk, heimdallr, moshe, ques, roommates
# Nearest to all:bacher, basica, unikom, ddg, deliverance, vedas, ridley, nmi
# Nearest to placed:keenly, caria, buell, caliph, result, blows, roots, insults
# Nearest to question:providential, wct, fuji, dairies, invitation, therapy, catwalk, emanating
# Nearest to versions:unquestioning, manifesto, subiaco, trainer, lehrer, pastorius, cora, digges
# Nearest to defense:durst, parachute, surrealistic, musicals, stonecutters, cymru, womack, sanity
# Nearest to pressure:sectioned, ponds, recreating, pleasuredome, moi, donating, warnings, mass
# Nearest to governor:savior, solving, edvac, participated, landforms, undesired, meaning, australians
# Nearest to san:administered, sleepers, suetonius, longsword, forget, prentice, compose, academics
# Nearest to heavy:hallelujah, disappointments, helping, representable, properties, nhs, vegans, kabuki
# Epoch 1/12 Iteration: 1100 Avg. Training loss: 5.5040 0.0484 sec/batch
# Epoch 1/12 Iteration: 1200 Avg. Training loss: 5.3582 0.0474 sec/batch
# Epoch 1/12 Iteration: 1300 Avg. Training loss: 5.3406 0.0478 sec/batch
# Epoch 1/12 Iteration: 1400 Avg. Training loss: 5.2703 0.0476 sec/batch
# Epoch 1/12 Iteration: 1500 Avg. Training loss: 5.1871 0.0479 sec/batch
# Epoch 1/12 Iteration: 1600 Avg. Training loss: 5.1922 0.0477 sec/batch
# Epoch 1/12 Iteration: 1700 Avg. Training loss: 5.1038 0.0475 sec/batch
# Epoch 1/12 Iteration: 1800 Avg. Training loss: 5.0753 0.0475 sec/batch
# Epoch 1/12 Iteration: 1900 Avg. Training loss: 5.0221 0.0477 sec/batch
# Epoch 1/12 Iteration: 2000 Avg. Training loss: 4.9901 0.0473 sec/batch
# Nearest to between:intimate, surround, radio, appropriation, totally, spontaneous, himself, lead
# Nearest to however:michele, eleusis, hanover, were, than, complexity, reviewers, anything
# Nearest to eight:lynch, yoruba, dials, kelly, taken, amendments, vitro, vida
# Nearest to history:testing, great, olaf, darwinism, whipple, amsterdam, firearm, yalta
# Nearest to in:conducted, lysis, metres, cartoon, contain, maxim, quality, crush
# Nearest to who:enough, manslaughter, retained, nevers, faraway, aguilera, sections, trinkets
# Nearest to two:measure, side, under, saw, punk, beech, coordinating, agha
# Nearest to all:consistent, persuaded, that, bacher, ddg, deliverance, basica, computed
# Nearest to placed:keenly, result, areas, roots, everything, predecessor, newman, caliph
# Nearest to question:providential, fuji, wct, therapy, invitation, expresses, indiana, joe
# Nearest to versions:unquestioning, manifesto, subiaco, don, flag, trips, orders, superhero
# Nearest to defense:musicals, sanity, shows, criminal, durst, parachute, quarters, cymru
# Nearest to pressure:sipe, donating, mass, fittings, warnings, fixed, limitations, moi
# Nearest to governor:savior, solving, participated, meaning, edvac, ahead, status, remoteness
# Nearest to san:administered, sleepers, forget, suetonius, longsword, academics, compose, prentice
# Nearest to heavy:helping, hallelujah, properties, disappointments, unfolding, montparnasse, kabuki, depict
# Epoch 1/12 Iteration: 2100 Avg. Training loss: 4.9444 0.0484 sec/batch
# Epoch 1/12 Iteration: 2200 Avg. Training loss: 4.9113 0.0474 sec/batch
# Epoch 1/12 Iteration: 2300 Avg. Training loss: 4.8991 0.0474 sec/batch
# Epoch 1/12 Iteration: 2400 Avg. Training loss: 4.8829 0.0473 sec/batch
# Epoch 1/12 Iteration: 2500 Avg. Training loss: 4.8003 0.0474 sec/batch
# Epoch 1/12 Iteration: 2600 Avg. Training loss: 4.8351 0.0476 sec/batch
# Epoch 1/12 Iteration: 2700 Avg. Training loss: 4.7999 0.0475 sec/batch
# Epoch 1/12 Iteration: 2800 Avg. Training loss: 4.7957 0.0474 sec/batch
# Epoch 1/12 Iteration: 2900 Avg. Training loss: 4.7937 0.0475 sec/batch
# Epoch 1/12 Iteration: 3000 Avg. Training loss: 4.7684 0.0476 sec/batch
# Nearest to between:appropriation, intimate, hurt, spontaneous, surround, reformed, likelihood, englishman
# Nearest to however:michele, eleusis, reviewers, gift, giraud, hanover, anything, composed
# Nearest to eight:lynch, yoruba, stanford, seine, dials, england, dymaxion, vitro
# Nearest to history:amsterdam, whipple, testing, firearm, darwinism, great, olaf, yalta
# Nearest to in:conducted, lysis, crush, methodical, maxim, cartoon, metres, contain
# Nearest to who:enough, manslaughter, retained, nevers, trinkets, faraway, mikhail, skyscrapers
# Nearest to two:won, measure, under, coordinating, beech, furthermore, side, manners
# Nearest to all:consistent, persuaded, bacher, that, deliverance, shake, pauline, resilient
# Nearest to placed:keenly, result, roots, blows, newman, alliances, secure, everything
# Nearest to question:expresses, providential, ill, invitation, therapy, fuji, wct, joe
# Nearest to versions:unquestioning, manifesto, flag, subiaco, trainer, trips, orders, superhero
# Nearest to defense:shows, cymru, criminal, stonecutters, sanity, durst, dedication, parachute
# Nearest to pressure:mass, fixed, fittings, comeback, thee, donating, warnings, limitations
# Nearest to governor:savior, solving, participated, incorrectly, remoteness, meaning, thicker, status
# Nearest to san:administered, sleepers, prentice, forget, compose, suetonius, longsword, academics
# Nearest to heavy:helping, hallelujah, properties, depict, communicating, montparnasse, unfolding, disappointments
# Epoch 1/12 Iteration: 3100 Avg. Training loss: 4.7988 0.0488 sec/batch
# Epoch 1/12 Iteration: 3200 Avg. Training loss: 4.7607 0.0473 sec/batch
# Epoch 1/12 Iteration: 3300 Avg. Training loss: 4.7201 0.0478 sec/batch
# Epoch 1/12 Iteration: 3400 Avg. Training loss: 4.7089 0.0473 sec/batch
# Epoch 1/12 Iteration: 3500 Avg. Training loss: 4.7454 0.0476 sec/batch
# Epoch 1/12 Iteration: 3600 Avg. Training loss: 4.7066 0.0473 sec/batch
# Epoch 1/12 Iteration: 3700 Avg. Training loss: 4.6988 0.0477 sec/batch
# Epoch 1/12 Iteration: 3800 Avg. Training loss: 4.7140 0.0475 sec/batch
# Epoch 1/12 Iteration: 3900 Avg. Training loss: 4.7021 0.0476 sec/batch
# Epoch 1/12 Iteration: 4000 Avg. Training loss: 4.6714 0.0473 sec/batch
# Nearest to between:appropriation, intimate, levitical, surround, englishman, reduces, hurt, convent
# Nearest to however:michele, giraud, gift, reviewers, eleusis, hanover, shipwrecked, involved
# Nearest to eight:physicist, lynch, england, yoruba, seine, stanford, dymaxion, anticipate
# Nearest to history:amsterdam, whipple, darwinism, outspoken, yalta, great, olaf, firearm
# Nearest to in:lysis, conducted, crush, warring, contain, suffrage, metres, methodical
# Nearest to who:enough, manslaughter, retained, neville, trinkets, mentors, lesotho, yoshitaka
# Nearest to two:won, under, ed, award, beech, stakes, mann, nicklaus
# Nearest to all:bacher, persuaded, consistent, deliverance, resilient, shake, pauline, that
# Nearest to placed:keenly, caliph, result, blows, areas, insults, newman, alliances
# Nearest to question:providential, fuji, expresses, ill, pythagorean, wct, negation, therapy
# Nearest to versions:unquestioning, manifesto, subiaco, lehrer, pastorius, trainer, flag, superhero
# Nearest to defense:cymru, durst, pu, stonecutters, sewage, criminal, sanity, harrier
# Nearest to pressure:fixed, mass, thee, ponds, recreating, comeback, fittings, warnings
# Nearest to governor:savior, solving, australians, participated, miriam, glorious, remoteness, governorates
# Nearest to san:administered, sleepers, prentice, longsword, compose, suetonius, hayao, forget
# Nearest to heavy:helping, hallelujah, kabuki, properties, unfolding, depict, liquid, sf
# Epoch 1/12 Iteration: 4100 Avg. Training loss: 4.6756 0.0485 sec/batch
# Epoch 1/12 Iteration: 4200 Avg. Training loss: 4.6881 0.0475 sec/batch
# Epoch 1/12 Iteration: 4300 Avg. Training loss: 4.6024 0.0477 sec/batch
# Epoch 1/12 Iteration: 4400 Avg. Training loss: 4.6281 0.0477 sec/batch
# Epoch 1/12 Iteration: 4500 Avg. Training loss: 4.6273 0.0472 sec/batch
# Epoch 1/12 Iteration: 4600 Avg. Training loss: 4.6153 0.0475 sec/batch
# Epoch 2/12 Iteration: 4700 Avg. Training loss: 4.6089 0.0355 sec/batch
# Epoch 2/12 Iteration: 4800 Avg. Training loss: 4.5673 0.0475 sec/batch
# Epoch 2/12 Iteration: 4900 Avg. Training loss: 4.5273 0.0473 sec/batch
# Epoch 2/12 Iteration: 5000 Avg. Training loss: 4.5021 0.0475 sec/batch
# Nearest to between:appropriation, intimate, convent, surround, levitical, pentium, anabaptism, decayed
# Nearest to however:giraud, michele, gift, shipwrecked, theists, involved, eleusis, hanover
# Nearest to eight:physicist, england, inventor, seven, lynch, two, nine, seine
# Nearest to history:darwinism, whipple, amsterdam, outspoken, manx, yalta, great, testing
# Nearest to in:crush, conducted, lysis, remarkably, warring, eventful, installing, trolltech
# Nearest to who:manslaughter, retained, enough, trinkets, faraway, mentors, skyscrapers, yoshitaka
# Nearest to two:won, three, six, ed, award, zero, actress, eight
# Nearest to all:consistent, resilient, bacher, that, deliverance, persuaded, unikom, basica
# Nearest to placed:keenly, caliph, peaks, result, insults, blows, alliances, caria
# Nearest to question:providential, expresses, ill, wct, fuji, pythagorean, couple, formulas
# Nearest to versions:unquestioning, manifesto, pastorius, lehrer, trainer, subiaco, pursuance, plaintiff
# Nearest to defense:durst, pu, stonecutters, cymru, criminal, harrier, sanity, melanesian
# Nearest to pressure:fixed, mass, ponds, limitations, thee, recreating, fittings, sipe
# Nearest to governor:savior, miriam, australians, solving, participated, glorious, mun, redacted
# Nearest to san:administered, sleepers, prentice, hayao, compose, longsword, suetonius, liouville
# Nearest to heavy:helping, hallelujah, kabuki, unfolding, disappointments, odham, depict, sf
# Epoch 2/12 Iteration: 5100 Avg. Training loss: 4.4796 0.0488 sec/batch
# Epoch 2/12 Iteration: 5200 Avg. Training loss: 4.4933 0.0473 sec/batch
# Epoch 2/12 Iteration: 5300 Avg. Training loss: 4.4666 0.0477 sec/batch
# Epoch 2/12 Iteration: 5400 Avg. Training loss: 4.5346 0.0474 sec/batch
# Epoch 2/12 Iteration: 5500 Avg. Training loss: 4.4816 0.0477 sec/batch
# Epoch 2/12 Iteration: 5600 Avg. Training loss: 4.4692 0.0474 sec/batch
# Epoch 2/12 Iteration: 5700 Avg. Training loss: 4.4561 0.0472 sec/batch
# Epoch 2/12 Iteration: 5800 Avg. Training loss: 4.4002 0.0474 sec/batch
# Epoch 2/12 Iteration: 5900 Avg. Training loss: 4.4555 0.0476 sec/batch
# Epoch 2/12 Iteration: 6000 Avg. Training loss: 4.4004 0.0474 sec/batch
# Nearest to between:appropriation, levitical, intimate, anabaptism, surround, goeldi, convent, pentium
# Nearest to however:giraud, michele, gift, shipwrecked, theists, bokuto, lawyers, involved
# Nearest to eight:physicist, yoruba, lynch, zero, homepage, hispanic, england, schlick
# Nearest to history:whipple, amsterdam, darwinism, outspoken, improvisations, manx, adel, great
# Nearest to in:lysis, crush, conducted, installing, remarkably, eventful, warring, cantonese
# Nearest to who:manslaughter, retained, trinkets, enough, congregation, yoshitaka, sins, nevers
# Nearest to two:zero, three, six, ed, walser, insecure, under, won
# Nearest to all:that, resilient, consistent, deliverance, persuaded, rotates, coerced, encode
# Nearest to placed:keenly, blows, caria, insults, areas, result, peaks, alliances
# Nearest to question:providential, expresses, ill, negation, pythagorean, wct, formulas, delinquent
# Nearest to versions:unquestioning, pastorius, standard, pursuance, trainer, lehrer, formats, manifesto
# Nearest to defense:cymru, harrier, durst, stonecutters, pu, criminal, sanity, melanesian
# Nearest to pressure:fixed, mass, ponds, limitations, additives, recreating, thee, sipe
# Nearest to governor:savior, miriam, australians, participated, redacted, remoteness, glorious, mun
# Nearest to san:administered, hayao, sleepers, prentice, arma, longsword, suetonius, liouville
# Nearest to heavy:helping, hallelujah, kabuki, disappointments, odham, vegans, radium, unfolding
# Epoch 2/12 Iteration: 6100 Avg. Training loss: 4.4428 0.0484 sec/batch
# Epoch 2/12 Iteration: 6200 Avg. Training loss: 4.4086 0.0472 sec/batch
# Epoch 2/12 Iteration: 6300 Avg. Training loss: 4.4464 0.0472 sec/batch
# Epoch 2/12 Iteration: 6400 Avg. Training loss: 4.3857 0.0472 sec/batch
# Epoch 2/12 Iteration: 6500 Avg. Training loss: 4.3940 0.0473 sec/batch
# Epoch 2/12 Iteration: 6600 Avg. Training loss: 4.4395 0.0474 sec/batch
# Epoch 2/12 Iteration: 6700 Avg. Training loss: 4.3866 0.0477 sec/batch
# Epoch 2/12 Iteration: 6800 Avg. Training loss: 4.3332 0.0474 sec/batch
# Epoch 2/12 Iteration: 6900 Avg. Training loss: 4.3797 0.0475 sec/batch
# Epoch 2/12 Iteration: 7000 Avg. Training loss: 4.3654 0.0476 sec/batch
# Nearest to between:levitical, appropriation, intimate, surround, anabaptism, goeldi, hurt, convent
# Nearest to however:giraud, michele, shipwrecked, theists, gift, siliceous, telepaths, scrimmage
# Nearest to eight:physicist, inventor, homepage, lynch, yoruba, zero, leuven, four
# Nearest to history:whipple, amsterdam, darwinism, outspoken, improvisations, adel, manx, olaf
# Nearest to in:lysis, crush, contain, warring, conducted, installing, eventful, deliberately
# Nearest to who:yoshitaka, manslaughter, trinkets, sins, congregation, procopius, chant, retained
# Nearest to two:three, zero, six, one, under, ed, walser, won
# Nearest to all:that, resilient, consistent, deliverance, encode, persuaded, ddg, unikom
# Nearest to placed:keenly, caria, insults, blows, paulinus, posture, caro, peaks
# Nearest to question:providential, expresses, wct, negation, ill, delinquent, couple, pythagorean
# Nearest to versions:unquestioning, formats, standard, lehrer, pastorius, diatonic, trainer, pursuance
# Nearest to defense:criminal, durst, stonecutters, pu, cymru, harrier, renewed, melanesian
# Nearest to pressure:fixed, mass, ponds, limitations, additives, recreating, thee, sipe
# Nearest to governor:savior, australians, miriam, mun, remoteness, participated, elias, redacted
# Nearest to san:administered, hayao, sleepers, prentice, jose, longsword, arma, bolognini
# Nearest to heavy:hallelujah, helping, kabuki, disappointments, radium, liquid, vegans, odham
# Epoch 2/12 Iteration: 7100 Avg. Training loss: 4.3684 0.0489 sec/batch
# Epoch 2/12 Iteration: 7200 Avg. Training loss: 4.3592 0.0475 sec/batch
# Epoch 2/12 Iteration: 7300 Avg. Training loss: 4.3618 0.0474 sec/batch
# Epoch 2/12 Iteration: 7400 Avg. Training loss: 4.3499 0.0485 sec/batch
# Epoch 2/12 Iteration: 7500 Avg. Training loss: 4.3950 0.0478 sec/batch
# Epoch 2/12 Iteration: 7600 Avg. Training loss: 4.3695 0.0479 sec/batch
# Epoch 2/12 Iteration: 7700 Avg. Training loss: 4.3656 0.0477 sec/batch
# Epoch 2/12 Iteration: 7800 Avg. Training loss: 4.3566 0.0478 sec/batch
# Epoch 2/12 Iteration: 7900 Avg. Training loss: 4.3205 0.0477 sec/batch
# Epoch 2/12 Iteration: 8000 Avg. Training loss: 4.3072 0.0476 sec/batch
# Nearest to between:levitical, appropriation, anabaptism, goeldi, hurt, surround, warships, convent
# Nearest to however:giraud, michele, electing, siliceous, shipwrecked, theists, grasshoppers, involved
# Nearest to eight:homepage, zero, two, four, physicist, one, inventor, yoruba
# Nearest to history:amsterdam, whipple, manx, outspoken, germanisation, darwinism, great, improvisations
# Nearest to in:crush, warring, contain, conducted, sufis, maxim, deliberately, cantonese
# Nearest to who:yoshitaka, congregation, retained, enough, sins, trinkets, manslaughter, cried
# Nearest to two:three, one, zero, six, under, eight, five, walser
# Nearest to all:that, resilient, consistent, persuaded, deliverance, encode, coerced, basica
# Nearest to placed:keenly, caria, insults, blows, caro, posture, paulinus, tip
# Nearest to question:providential, expresses, delinquent, ill, wct, negation, truly, couple
# Nearest to versions:unquestioning, formats, standard, superhero, pastorius, compatibles, diatonic, lehrer
# Nearest to defense:criminal, stonecutters, durst, harrier, cymru, sanity, renewed, cello
# Nearest to pressure:fixed, mass, ponds, recreating, additives, donating, limitations, explosions
# Nearest to governor:savior, australians, miriam, mun, redacted, participated, gatherers, remoteness
# Nearest to san:administered, hayao, sleepers, jose, prentice, arma, longsword, bolognini
# Nearest to heavy:liquid, hallelujah, kabuki, odham, helping, radium, percussive, vegans
# Epoch 2/12 Iteration: 8100 Avg. Training loss: 4.3617 0.0486 sec/batch
# Epoch 2/12 Iteration: 8200 Avg. Training loss: 4.2968 0.0475 sec/batch
# Epoch 2/12 Iteration: 8300 Avg. Training loss: 4.3673 0.0476 sec/batch
# Epoch 2/12 Iteration: 8400 Avg. Training loss: 4.3542 0.0477 sec/batch
# Epoch 2/12 Iteration: 8500 Avg. Training loss: 4.3513 0.0476 sec/batch
# Epoch 2/12 Iteration: 8600 Avg. Training loss: 4.2877 0.0479 sec/batch
# Epoch 2/12 Iteration: 8700 Avg. Training loss: 4.2811 0.0476 sec/batch
# Epoch 2/12 Iteration: 8800 Avg. Training loss: 4.3176 0.0476 sec/batch
# Epoch 2/12 Iteration: 8900 Avg. Training loss: 4.2241 0.0475 sec/batch
# Epoch 2/12 Iteration: 9000 Avg. Training loss: 4.3012 0.0475 sec/batch
# Nearest to between:levitical, appropriation, goeldi, anabaptism, convent, surround, hurt, warships
# Nearest to however:giraud, grasshoppers, electing, michele, siliceous, porpoises, shipwrecked, anarchic
# Nearest to eight:zero, two, physicist, four, one, nine, inventor, seven
# Nearest to history:whipple, germanisation, amsterdam, manx, darwinism, outspoken, improvisations, th
# Nearest to in:warring, crush, lysis, eventful, sufis, conducted, bokm, installing
# Nearest to who:yoshitaka, trinkets, congregation, sins, mentors, enough, cried, procopius
# Nearest to two:zero, three, one, six, eight, five, under, ed
# Nearest to all:that, resilient, consistent, persuaded, coerced, brews, basica, bacher
# Nearest to placed:keenly, insults, caro, tip, mcm, blows, caria, posture
# Nearest to question:providential, expresses, negation, wct, delinquent, dialectic, scoundrel, emanating
# Nearest to versions:unquestioning, formats, standard, console, superhero, compatibles, lehrer, pastorius
# Nearest to defense:criminal, stonecutters, durst, cymru, harrier, sanity, renewed, macanese
# Nearest to pressure:fixed, ponds, mass, donating, explosions, additives, pleasuredome, recreating
# Nearest to governor:savior, miriam, australians, mun, elias, branch, congress, redacted
# Nearest to san:administered, hayao, jose, arma, sleepers, compose, alameda, prentice
# Nearest to heavy:liquid, hallelujah, odham, kabuki, percussive, helping, vegans, waterfalls
# Epoch 2/12 Iteration: 9100 Avg. Training loss: 4.3178 0.0488 sec/batch
# Epoch 2/12 Iteration: 9200 Avg. Training loss: 4.2755 0.0476 sec/batch
# Epoch 3/12 Iteration: 9300 Avg. Training loss: 4.3261 0.0234 sec/batch
# Epoch 3/12 Iteration: 9400 Avg. Training loss: 4.2483 0.0475 sec/batch
# Epoch 3/12 Iteration: 9500 Avg. Training loss: 4.2348 0.0475 sec/batch
# Epoch 3/12 Iteration: 9600 Avg. Training loss: 4.2002 0.0475 sec/batch
# Epoch 3/12 Iteration: 9700 Avg. Training loss: 4.1944 0.0474 sec/batch
# Epoch 3/12 Iteration: 9800 Avg. Training loss: 4.2039 0.0476 sec/batch
# Epoch 3/12 Iteration: 9900 Avg. Training loss: 4.2121 0.0478 sec/batch
# Epoch 3/12 Iteration: 10000 Avg. Training loss: 4.1814 0.0476 sec/batch
# Nearest to between:levitical, goeldi, appropriation, surround, anabaptism, decayed, convent, hurt
# Nearest to however:siliceous, electing, grasshoppers, porpoises, giraud, theists, bokuto, michele
# Nearest to eight:zero, two, four, homepage, db, rate, hutton, three
# Nearest to history:germanisation, amsterdam, whipple, manx, darwinism, improvisations, outspoken, th
# Nearest to in:crush, eventful, maltin, keita, expanded, lysis, contain, bokm
# Nearest to who:yoshitaka, trinkets, retained, congregation, cried, mentors, procopius, enough
# Nearest to two:zero, three, six, one, five, eight, under, ed
# Nearest to all:that, resilient, rotates, coerced, consistent, persuaded, deliverance, computed
# Nearest to placed:keenly, insults, caro, mcm, tip, posture, direction, coax
# Nearest to question:providential, expresses, wct, delinquent, emanating, negation, dialectic, scoundrel
# Nearest to versions:unquestioning, standard, formats, console, compatibles, pastorius, developers, lehrer
# Nearest to defense:criminal, harrier, sanity, macanese, renewed, durst, bulletins, stonecutters
# Nearest to pressure:fixed, ponds, mass, donating, pleasuredome, additives, explosions, barite
# Nearest to governor:savior, australians, miriam, mun, congress, appointments, branch, gatherers
# Nearest to san:administered, hayao, jose, arma, sleepers, alameda, prentice, bolognini
# Nearest to heavy:liquid, odham, hallelujah, kabuki, helping, percussive, vegans, blasting
# Epoch 3/12 Iteration: 10100 Avg. Training loss: 4.2249 0.0486 sec/batch
# Epoch 3/12 Iteration: 10200 Avg. Training loss: 4.1977 0.0475 sec/batch
# Epoch 3/12 Iteration: 10300 Avg. Training loss: 4.1935 0.0475 sec/batch
# Epoch 3/12 Iteration: 10400 Avg. Training loss: 4.1227 0.0475 sec/batch
# Epoch 3/12 Iteration: 10500 Avg. Training loss: 4.1606 0.0474 sec/batch
# Epoch 3/12 Iteration: 10600 Avg. Training loss: 4.1373 0.0473 sec/batch
# Epoch 3/12 Iteration: 10700 Avg. Training loss: 4.1375 0.0472 sec/batch
# Epoch 3/12 Iteration: 10800 Avg. Training loss: 4.1458 0.0476 sec/batch
# Epoch 3/12 Iteration: 10900 Avg. Training loss: 4.1678 0.0475 sec/batch
# Epoch 3/12 Iteration: 11000 Avg. Training loss: 4.1705 0.0474 sec/batch
# Nearest to between:levitical, thermodynamic, surround, goeldi, decayed, appropriation, anabaptism, visualized
# Nearest to however:siliceous, porpoises, electing, grasshoppers, giraud, bokuto, interbase, theists
# Nearest to eight:zero, four, two, db, three, rt, five, rate
# Nearest to history:germanisation, amsterdam, whipple, manx, improvisations, darwinism, science, outspoken
# Nearest to in:contain, eventful, seeded, canalized, minimis, lysis, expanded, dalhousie
# Nearest to who:yoshitaka, trinkets, cried, procopius, chant, congregation, sins, enough
# Nearest to two:zero, three, one, six, five, under, eight, four
# Nearest to all:that, resilient, coerced, rotates, consistent, weak, brews, encode
# Nearest to placed:keenly, insults, tip, mcm, posture, smoothness, caria, shaped
# Nearest to question:providential, expresses, negation, delinquent, wct, dialectic, emanating, pythagorean
# Nearest to versions:unquestioning, formats, pastorius, superhero, standard, console, compatibles, diatonic
# Nearest to defense:criminal, harrier, macanese, sanity, durst, pu, bulletins, renewed
# Nearest to pressure:ponds, mass, fixed, donating, explosions, additives, pleasuredome, barite
# Nearest to governor:branch, australians, appointments, mun, gatherers, savior, congress, miriam
# Nearest to san:jose, hayao, administered, alameda, arma, dior, cordillera, sleepers
# Nearest to heavy:liquid, blasting, kabuki, odham, hallelujah, waterfalls, percussive, helping
# Epoch 3/12 Iteration: 11100 Avg. Training loss: 4.1697 0.0489 sec/batch
# Epoch 3/12 Iteration: 11200 Avg. Training loss: 4.2199 0.0475 sec/batch
# Epoch 3/12 Iteration: 11300 Avg. Training loss: 4.1730 0.0473 sec/batch
# Epoch 3/12 Iteration: 11400 Avg. Training loss: 4.1133 0.0476 sec/batch
# Epoch 3/12 Iteration: 11500 Avg. Training loss: 4.1334 0.0475 sec/batch
# Epoch 3/12 Iteration: 11600 Avg. Training loss: 4.1359 0.0474 sec/batch
# Epoch 3/12 Iteration: 11700 Avg. Training loss: 4.1736 0.0475 sec/batch
# Epoch 3/12 Iteration: 11800 Avg. Training loss: 4.1167 0.0475 sec/batch
# Epoch 3/12 Iteration: 11900 Avg. Training loss: 4.1420 0.0474 sec/batch
# Epoch 3/12 Iteration: 12000 Avg. Training loss: 4.1370 0.0475 sec/batch
# Nearest to between:levitical, hurt, thermodynamic, decayed, surround, goeldi, anabaptism, appropriation
# Nearest to however:electing, siliceous, thal, porpoises, grasshoppers, giraud, bokuto, michele
# Nearest to eight:zero, four, two, one, three, five, rate, nine
# Nearest to history:germanisation, whipple, darwinism, manx, grecian, science, amsterdam, improvisations
# Nearest to in:contain, eventful, deliberately, minimis, fielder, first, expanded, detailed
# Nearest to who:yoshitaka, cried, trinkets, procopius, retained, enough, chant, congregation
# Nearest to two:three, zero, one, six, five, eight, under, four
# Nearest to all:that, coerced, rotates, resilient, product, brews, ddg, consistent
# Nearest to placed:keenly, tip, insults, mcm, caria, posture, smoothness, shaped
# Nearest to question:providential, expresses, negation, wct, delinquent, dialectic, emanating, attempts
# Nearest to versions:unquestioning, superhero, diatonic, console, subiaco, pastorius, trainer, formats
# Nearest to defense:criminal, macanese, harrier, sanity, durst, kart, cleverness, pu
# Nearest to pressure:mass, ponds, fixed, donating, explosions, pleasuredome, litres, barite
# Nearest to governor:mun, branch, australians, miriam, savior, appointments, donations, gatherers
# Nearest to san:administered, jose, hayao, dior, alameda, arma, sleepers, cordillera
# Nearest to heavy:liquid, odham, kabuki, blasting, hallelujah, percussive, helping, pressed
# Epoch 3/12 Iteration: 12100 Avg. Training loss: 4.1661 0.0485 sec/batch
# Epoch 3/12 Iteration: 12200 Avg. Training loss: 4.1867 0.0478 sec/batch
# Epoch 3/12 Iteration: 12300 Avg. Training loss: 4.1619 0.0477 sec/batch
# Epoch 3/12 Iteration: 12400 Avg. Training loss: 4.1484 0.0480 sec/batch
# Epoch 3/12 Iteration: 12500 Avg. Training loss: 4.1401 0.0474 sec/batch
# Epoch 3/12 Iteration: 12600 Avg. Training loss: 4.0820 0.0472 sec/batch
# Epoch 3/12 Iteration: 12700 Avg. Training loss: 4.1313 0.0473 sec/batch
# Epoch 3/12 Iteration: 12800 Avg. Training loss: 4.1174 0.0476 sec/batch
# Epoch 3/12 Iteration: 12900 Avg. Training loss: 4.1690 0.0475 sec/batch
# Epoch 3/12 Iteration: 13000 Avg. Training loss: 4.2116 0.0476 sec/batch
# Nearest to between:levitical, anabaptism, goeldi, surround, appropriation, convent, in, decayed
# Nearest to however:electing, thal, porpoises, siliceous, gdi, michele, conservatism, shipwrecked
# Nearest to eight:zero, two, four, one, five, three, nine, seven
# Nearest to history:germanisation, science, whipple, th, darwinism, grecian, amsterdam, improvisations
# Nearest to in:fielder, position, with, crush, first, konar, between, somali
# Nearest to who:yoshitaka, cried, mentors, trinkets, hosea, procopius, jstor, insurrection
# Nearest to two:three, zero, one, six, five, eight, four, under
# Nearest to all:that, coerced, rotates, resilient, brews, product, weak, basica
# Nearest to placed:keenly, insults, tip, caria, mcm, posture, coax, structure
# Nearest to question:providential, expresses, negation, wct, emanating, delinquent, pythagorean, dialectic
# Nearest to versions:unquestioning, superhero, diatonic, tutorials, subiaco, console, compatibles, synthesizer
# Nearest to defense:criminal, macanese, sanity, harrier, durst, cleverness, wounding, kart
# Nearest to pressure:mass, ponds, donating, fixed, barite, explosions, pleasuredome, thee
# Nearest to governor:miriam, mun, branch, australians, gatherers, solving, congress, steamer
# Nearest to san:jose, administered, hayao, dior, sleepers, alameda, croix, arma
# Nearest to heavy:liquid, odham, blasting, helping, kabuki, hallelujah, percussive, pressed
# Epoch 3/12 Iteration: 13100 Avg. Training loss: 4.1828 0.0487 sec/batch
# Epoch 3/12 Iteration: 13200 Avg. Training loss: 4.1261 0.0477 sec/batch
# Epoch 3/12 Iteration: 13300 Avg. Training loss: 4.1069 0.0476 sec/batch
# Epoch 3/12 Iteration: 13400 Avg. Training loss: 4.1106 0.0474 sec/batch
# Epoch 3/12 Iteration: 13500 Avg. Training loss: 3.9834 0.0475 sec/batch
# Epoch 3/12 Iteration: 13600 Avg. Training loss: 4.1229 0.0477 sec/batch
# Epoch 3/12 Iteration: 13700 Avg. Training loss: 4.1178 0.0474 sec/batch
# Epoch 3/12 Iteration: 13800 Avg. Training loss: 4.0962 0.0474 sec/batch
# Epoch 4/12 Iteration: 13900 Avg. Training loss: 4.1533 0.0111 sec/batch
# Epoch 4/12 Iteration: 14000 Avg. Training loss: 4.0638 0.0476 sec/batch
# Nearest to between:levitical, goeldi, surround, anabaptism, decayed, thermodynamic, sun, lufthansa
# Nearest to however:electing, porpoises, thal, grasshoppers, siliceous, gdi, bokuto, ignition
# Nearest to eight:zero, two, four, one, five, three, nine, six
# Nearest to history:germanisation, science, whipple, th, darwinism, amsterdam, improvisations, grecian
# Nearest to in:expanded, with, fielder, konar, first, maltin, several, eventful
# Nearest to who:yoshitaka, cried, enough, procopius, trinkets, jstor, villa, mentors
# Nearest to two:zero, three, one, six, five, eight, four, nine
# Nearest to all:that, rotates, coerced, resilient, product, brews, weak, basica
# Nearest to placed:keenly, tip, mcm, coax, hellen, shaped, insults, lined
# Nearest to question:providential, expresses, wct, emanating, negation, delinquent, dialectic, pythagorean
# Nearest to versions:unquestioning, developers, console, superhero, tutorials, compatibles, standard, levers
# Nearest to defense:macanese, criminal, sanity, harrier, durst, bulletins, kart, extradition
# Nearest to pressure:mass, donating, ponds, fixed, pleasuredome, explosions, thee, conditioner
# Nearest to governor:branch, mun, congress, miriam, gatherers, steamer, solving, australians
# Nearest to san:administered, jose, hayao, dior, alameda, sleepers, cordillera, arma
# Nearest to heavy:blasting, odham, hallelujah, liquid, helping, kabuki, percussive, katy
# Epoch 4/12 Iteration: 14100 Avg. Training loss: 4.0214 0.0486 sec/batch
# Epoch 4/12 Iteration: 14200 Avg. Training loss: 4.0379 0.0478 sec/batch
# Epoch 4/12 Iteration: 14300 Avg. Training loss: 4.0372 0.0478 sec/batch
# Epoch 4/12 Iteration: 14400 Avg. Training loss: 4.0304 0.0479 sec/batch
# Epoch 4/12 Iteration: 14500 Avg. Training loss: 4.0334 0.0474 sec/batch
# Epoch 4/12 Iteration: 14600 Avg. Training loss: 3.9915 0.0478 sec/batch
# Epoch 4/12 Iteration: 14700 Avg. Training loss: 4.0386 0.0474 sec/batch
# Epoch 4/12 Iteration: 14800 Avg. Training loss: 4.0583 0.0474 sec/batch
# Epoch 4/12 Iteration: 14900 Avg. Training loss: 4.0534 0.0474 sec/batch
# Epoch 4/12 Iteration: 15000 Avg. Training loss: 3.9835 0.0473 sec/batch
# Nearest to between:goeldi, anabaptism, surround, in, decayed, levitical, the, shifting
# Nearest to however:electing, porpoises, siliceous, gdi, giraud, simo, grasshoppers, thal
# Nearest to eight:zero, two, five, four, one, three, nine, six
# Nearest to history:germanisation, th, improvisations, science, amsterdam, grecian, whipple, lia
# Nearest to in:with, eventful, fielder, of, first, expanded, divisions, between
# Nearest to who:yoshitaka, trinkets, enough, cried, villa, retained, procopius, hosea
# Nearest to two:three, zero, one, six, five, eight, four, nine
# Nearest to all:coerced, rotates, that, resilient, weak, product, carnival, basica
# Nearest to placed:tip, keenly, mcm, coax, shaped, insults, posture, hellen
# Nearest to question:providential, expresses, negation, emanating, wct, pythagorean, delinquent, institutionalized
# Nearest to versions:unquestioning, trainer, console, subiaco, standard, synthesizer, lehrer, superhero
# Nearest to defense:macanese, criminal, harrier, sanity, parachute, extradition, bulletins, durst
# Nearest to pressure:mass, donating, ponds, pleasuredome, conditioner, litres, phishing, thee
# Nearest to governor:branch, congress, appointments, gatherers, mun, presides, miriam, steamer
# Nearest to san:jose, administered, hayao, alameda, dior, santa, cordillera, croix
# Nearest to heavy:blasting, odham, helping, kabuki, liquid, katy, hallelujah, percussive
# Epoch 4/12 Iteration: 15100 Avg. Training loss: 4.0208 0.0486 sec/batch
# Epoch 4/12 Iteration: 15200 Avg. Training loss: 3.9913 0.0475 sec/batch
# Epoch 4/12 Iteration: 15300 Avg. Training loss: 3.9657 0.0473 sec/batch
# Epoch 4/12 Iteration: 15400 Avg. Training loss: 4.0322 0.0476 sec/batch
# Epoch 4/12 Iteration: 15500 Avg. Training loss: 4.0450 0.0473 sec/batch
# Epoch 4/12 Iteration: 15600 Avg. Training loss: 4.0197 0.0471 sec/batch
# Epoch 4/12 Iteration: 15700 Avg. Training loss: 4.0277 0.0473 sec/batch
# Epoch 4/12 Iteration: 15800 Avg. Training loss: 4.0719 0.0474 sec/batch
# Epoch 4/12 Iteration: 15900 Avg. Training loss: 4.0382 0.0476 sec/batch
# Epoch 4/12 Iteration: 16000 Avg. Training loss: 4.0131 0.0473 sec/batch
# Nearest to between:in, surround, levitical, decayed, thermodynamic, anabaptism, the, goeldi
# Nearest to however:porpoises, electing, consenting, siliceous, be, gdi, ignition, bokuto
# Nearest to eight:zero, two, five, four, one, three, six, nine
# Nearest to history:germanisation, th, science, grecian, improvisations, darwinism, whipple, lia
# Nearest to in:of, between, with, first, eventful, the, expanded, divisions
# Nearest to who:yoshitaka, trinkets, cried, jstor, aegisthus, hosea, annul, offeror
# Nearest to two:three, zero, six, one, five, eight, four, nine
# Nearest to all:that, rotates, coerced, resilient, product, milliseconds, basica, weak
# Nearest to placed:keenly, tip, caria, insults, structure, coax, posture, cabling
# Nearest to question:providential, expresses, negation, emanating, wct, pythagorean, manipulating, goes
# Nearest to versions:unquestioning, lehrer, subiaco, trainer, diatonic, superhero, levers, pastorius
# Nearest to defense:macanese, sanity, criminal, harrier, extradition, parachute, pu, bulletins
# Nearest to pressure:mass, donating, ponds, fixed, pleasuredome, conditioner, thee, litres
# Nearest to governor:branch, congress, presides, gatherers, mun, steamer, miriam, appointments
# Nearest to san:jose, administered, hayao, alameda, santa, arma, dior, sleepers
# Nearest to heavy:liquid, blasting, helping, kabuki, odham, percussive, army, katy
# Epoch 4/12 Iteration: 16100 Avg. Training loss: 4.0327 0.0483 sec/batch
# Epoch 4/12 Iteration: 16200 Avg. Training loss: 4.0444 0.0472 sec/batch
# Epoch 4/12 Iteration: 16300 Avg. Training loss: 4.0657 0.0475 sec/batch
# Epoch 4/12 Iteration: 16400 Avg. Training loss: 3.9985 0.0474 sec/batch
# Epoch 4/12 Iteration: 16500 Avg. Training loss: 4.0520 0.0475 sec/batch
# Epoch 4/12 Iteration: 16600 Avg. Training loss: 4.0262 0.0473 sec/batch
# Epoch 4/12 Iteration: 16700 Avg. Training loss: 4.0219 0.0474 sec/batch
# Epoch 4/12 Iteration: 16800 Avg. Training loss: 4.0148 0.0474 sec/batch
# Epoch 4/12 Iteration: 16900 Avg. Training loss: 4.0632 0.0474 sec/batch
# Epoch 4/12 Iteration: 17000 Avg. Training loss: 4.0492 0.0473 sec/batch
# Nearest to between:in, levitical, anabaptism, hurt, goeldi, surround, the, shifting
# Nearest to however:electing, simo, porpoises, be, of, hanover, jedi, michele
# Nearest to eight:zero, two, one, five, three, four, six, nine
# Nearest to history:germanisation, grecian, th, lia, science, darwinism, improvisations, geographer
# Nearest to in:of, the, and, with, first, between, expanded, was
# Nearest to who:yoshitaka, offeror, trinkets, enough, cried, hosea, sharply, retained
# Nearest to two:three, zero, one, six, five, eight, four, nine
# Nearest to all:that, coerced, product, rotates, resilient, weak, unikom, of
# Nearest to placed:tip, keenly, hellen, caria, structure, buffering, lined, anderssen
# Nearest to question:providential, expresses, negation, wct, pythagorean, emanating, manipulating, pillows
# Nearest to versions:unquestioning, trainer, subiaco, lehrer, diatonic, superhero, pastorius, levers
# Nearest to defense:macanese, sanity, criminal, harrier, extradition, parachute, durst, wounding
# Nearest to pressure:mass, donating, ponds, thee, explosions, pleasuredome, litres, conditioner
# Nearest to governor:branch, gatherers, steamer, appointments, solving, congress, australians, mun
# Nearest to san:jose, administered, hayao, alameda, dior, santa, sleepers, croix
# Nearest to heavy:liquid, helping, odham, blasting, electronically, halving, kabuki, percussive
# Epoch 4/12 Iteration: 17100 Avg. Training loss: 4.0023 0.0485 sec/batch
# Epoch 4/12 Iteration: 17200 Avg. Training loss: 3.9597 0.0476 sec/batch
# Epoch 4/12 Iteration: 17300 Avg. Training loss: 3.9730 0.0473 sec/batch
# Epoch 4/12 Iteration: 17400 Avg. Training loss: 4.0632 0.0477 sec/batch
# Epoch 4/12 Iteration: 17500 Avg. Training loss: 4.0434 0.0474 sec/batch
# Epoch 4/12 Iteration: 17600 Avg. Training loss: 4.0947 0.0475 sec/batch
# Epoch 4/12 Iteration: 17700 Avg. Training loss: 4.0857 0.0475 sec/batch
# Epoch 4/12 Iteration: 17800 Avg. Training loss: 4.0046 0.0474 sec/batch
# Epoch 4/12 Iteration: 17900 Avg. Training loss: 4.0130 0.0472 sec/batch
# Epoch 4/12 Iteration: 18000 Avg. Training loss: 4.0240 0.0472 sec/batch
# Nearest to between:surround, goeldi, levitical, in, anabaptism, hurt, lufthansa, statistic
# Nearest to however:electing, porpoises, michele, be, consenting, gdi, bokuto, conservatism
# Nearest to eight:zero, two, one, nine, five, four, three, six
# Nearest to history:germanisation, grecian, th, science, darwinism, lia, whipple, improvisations
# Nearest to in:of, the, first, and, expanded, with, between, somali
# Nearest to who:yoshitaka, trinkets, cried, jstor, offeror, hosea, procopius, aegisthus
# Nearest to two:zero, three, one, six, five, eight, four, nine
# Nearest to all:that, product, coerced, rotates, weak, singly, resilient, brews
# Nearest to placed:tip, structure, keenly, caria, lined, cabling, buffering, hellen
# Nearest to question:providential, expresses, negation, wct, goes, pythagorean, manipulating, emanating
# Nearest to versions:unquestioning, subiaco, lehrer, superhero, trainer, levers, diatonic, developers
# Nearest to defense:macanese, sanity, criminal, harrier, extradition, parachute, durst, wounding
# Nearest to pressure:mass, donating, thee, explosions, litres, ponds, barite, pleasuredome
# Nearest to governor:branch, steamer, appointments, congress, gatherers, miriam, mun, solving
# Nearest to san:jose, administered, croix, santa, hayao, alameda, arma, dior
# Nearest to heavy:helping, odham, liquid, blasting, percussive, halving, hallelujah, electronically
# Epoch 4/12 Iteration: 18100 Avg. Training loss: 3.9173 0.0485 sec/batch
# Epoch 4/12 Iteration: 18200 Avg. Training loss: 3.9665 0.0475 sec/batch
# Epoch 4/12 Iteration: 18300 Avg. Training loss: 4.0041 0.0473 sec/batch
# Epoch 4/12 Iteration: 18400 Avg. Training loss: 3.9868 0.0475 sec/batch
# Epoch 4/12 Iteration: 18500 Avg. Training loss: 4.0465 0.0473 sec/batch
# Epoch 5/12 Iteration: 18600 Avg. Training loss: 3.9881 0.0460 sec/batch
# Epoch 5/12 Iteration: 18700 Avg. Training loss: 3.9696 0.0477 sec/batch
# Epoch 5/12 Iteration: 18800 Avg. Training loss: 3.9384 0.0473 sec/batch
# Epoch 5/12 Iteration: 18900 Avg. Training loss: 3.9961 0.0476 sec/batch
# Epoch 5/12 Iteration: 19000 Avg. Training loss: 3.9341 0.0474 sec/batch
# Nearest to between:surround, levitical, goeldi, anabaptism, in, hurt, decayed, lufthansa
# Nearest to however:electing, porpoises, be, consenting, ignition, michele, gdi, bokuto
# Nearest to eight:one, zero, nine, two, five, six, four, three
# Nearest to history:germanisation, th, grecian, science, darwinism, lia, annales, sherborne
# Nearest to in:of, first, and, the, expanded, with, a, was
# Nearest to who:yoshitaka, cried, trinkets, foreknowledge, offeror, hosea, villa, retained
# Nearest to two:zero, three, six, one, five, eight, four, nine
# Nearest to all:that, rotates, coerced, product, resilient, singly, brews, weak
# Nearest to placed:tip, structure, cabling, lined, keenly, coax, caria, hellen
# Nearest to question:providential, expresses, wct, negation, goes, emanating, manipulating, pythagorean
# Nearest to versions:unquestioning, subiaco, developers, trainer, levers, xx, standard, preprocessor
# Nearest to defense:macanese, sanity, criminal, harrier, parachute, durst, extradition, bulletins
# Nearest to pressure:mass, donating, litres, thee, conditioner, explosions, ponds, absorbing
# Nearest to governor:branch, steamer, gatherers, appointments, solving, congress, miriam, presides
# Nearest to san:jose, administered, hayao, croix, santa, alameda, dior, arma
# Nearest to heavy:odham, blasting, electronically, percussive, sundanese, helping, liquid, katy
# Epoch 5/12 Iteration: 19100 Avg. Training loss: 3.9649 0.0483 sec/batch
# Epoch 5/12 Iteration: 19200 Avg. Training loss: 3.8592 0.0474 sec/batch
# Epoch 5/12 Iteration: 19300 Avg. Training loss: 3.9868 0.0477 sec/batch
# Epoch 5/12 Iteration: 19400 Avg. Training loss: 3.9777 0.0472 sec/batch
# Epoch 5/12 Iteration: 19500 Avg. Training loss: 3.9864 0.0473 sec/batch
# Epoch 5/12 Iteration: 19600 Avg. Training loss: 3.9497 0.0475 sec/batch
# Epoch 5/12 Iteration: 19700 Avg. Training loss: 3.8771 0.0474 sec/batch
# Epoch 5/12 Iteration: 19800 Avg. Training loss: 3.9139 0.0474 sec/batch
# Epoch 5/12 Iteration: 19900 Avg. Training loss: 3.8840 0.0474 sec/batch
# Epoch 5/12 Iteration: 20000 Avg. Training loss: 3.9450 0.0473 sec/batch
# Nearest to between:in, surround, levitical, goeldi, hurt, effect, shifting, thermodynamic
# Nearest to however:porpoises, consenting, be, electing, siliceous, bokuto, basal, ignition
# Nearest to eight:zero, one, two, five, four, three, nine, six
# Nearest to history:germanisation, th, grecian, science, lia, improvisations, darwinism, sherborne
# Nearest to in:of, the, and, a, first, with, expanded, between
# Nearest to who:yoshitaka, trinkets, retained, offeror, cried, sharply, foreknowledge, aegisthus
# Nearest to two:one, zero, three, six, five, four, eight, nine
# Nearest to all:that, rotates, product, coerced, resilient, weak, set, singly
# Nearest to placed:tip, cabling, structure, buffering, ifv, caria, volusia, keenly
# Nearest to question:providential, expresses, negation, pythagorean, wct, manipulating, goes, institutionalized
# Nearest to versions:unquestioning, trainer, lehrer, subiaco, levers, superhero, xx, pastorius
# Nearest to defense:macanese, sanity, parachute, harrier, criminal, extradition, durst, subversives
# Nearest to pressure:donating, mass, litres, explosions, thee, conditioner, barite, pleasuredome
# Nearest to governor:branch, gatherers, steamer, presides, edvac, miriam, appointments, congress
# Nearest to san:jose, hayao, santa, administered, alameda, croix, dior, francisco
# Nearest to heavy:blasting, electronically, odham, helping, percussive, towed, sundanese, katy
# Epoch 5/12 Iteration: 20100 Avg. Training loss: 3.9527 0.0484 sec/batch
# Epoch 5/12 Iteration: 20200 Avg. Training loss: 3.9708 0.0474 sec/batch
# Epoch 5/12 Iteration: 20300 Avg. Training loss: 3.9462 0.0479 sec/batch
# Epoch 5/12 Iteration: 20400 Avg. Training loss: 3.9656 0.0477 sec/batch
# Epoch 5/12 Iteration: 20500 Avg. Training loss: 3.9903 0.0476 sec/batch
# Epoch 5/12 Iteration: 20600 Avg. Training loss: 3.9109 0.0478 sec/batch
# Epoch 5/12 Iteration: 20700 Avg. Training loss: 3.9730 0.0477 sec/batch
# Epoch 5/12 Iteration: 20800 Avg. Training loss: 3.9586 0.0478 sec/batch
# Epoch 5/12 Iteration: 20900 Avg. Training loss: 3.9805 0.0477 sec/batch
# Epoch 5/12 Iteration: 21000 Avg. Training loss: 3.9589 0.0476 sec/batch
# Nearest to between:hurt, in, surround, levitical, effect, anabaptism, executes, the
# Nearest to however:be, consenting, electing, porpoises, than, ignition, creighton, thal
# Nearest to eight:one, zero, nine, five, six, four, two, three
# Nearest to history:grecian, germanisation, th, darwinism, lia, annales, science, sherborne
# Nearest to in:of, the, first, and, a, with, expanded, roscoe
# Nearest to who:yoshitaka, offeror, aegisthus, cried, trinkets, retained, jstor, gahan
# Nearest to two:one, zero, three, six, five, eight, four, nine
# Nearest to all:that, coerced, of, rotates, product, weak, resilient, set
# Nearest to placed:tip, buffering, caria, cabling, volusia, structure, dixie, reproduces
# Nearest to question:providential, expresses, negation, goes, wct, manipulating, ghq, pythagorean
# Nearest to versions:unquestioning, trainer, lehrer, subiaco, levers, xx, superhero, cropped
# Nearest to defense:macanese, sanity, parachute, criminal, harrier, extradition, durst, pu
# Nearest to pressure:donating, mass, thee, explosions, heat, conditioner, barite, litres
# Nearest to governor:branch, steamer, gatherers, edvac, presides, appointments, donations, solving
# Nearest to san:jose, santa, administered, hayao, croix, alameda, francisco, arma
# Nearest to heavy:blasting, electronically, helping, odham, percussive, liquid, kabuki, sundanese
# Epoch 5/12 Iteration: 21100 Avg. Training loss: 3.9576 0.0487 sec/batch
# Epoch 5/12 Iteration: 21200 Avg. Training loss: 3.9399 0.0479 sec/batch
# Epoch 5/12 Iteration: 21300 Avg. Training loss: 3.9441 0.0477 sec/batch
# Epoch 5/12 Iteration: 21400 Avg. Training loss: 3.9590 0.0476 sec/batch
# Epoch 5/12 Iteration: 21500 Avg. Training loss: 3.9912 0.0472 sec/batch
# Epoch 5/12 Iteration: 21600 Avg. Training loss: 3.9497 0.0480 sec/batch
# Epoch 5/12 Iteration: 21700 Avg. Training loss: 3.9303 0.0479 sec/batch
# Epoch 5/12 Iteration: 21800 Avg. Training loss: 3.9293 0.0479 sec/batch
# Epoch 5/12 Iteration: 21900 Avg. Training loss: 3.9126 0.0477 sec/batch
# Epoch 5/12 Iteration: 22000 Avg. Training loss: 3.9904 0.0475 sec/batch
# Nearest to between:in, the, surround, with, effect, levitical, executes, goeldi
# Nearest to however:be, electing, porpoises, consenting, than, of, ignition, agulhas
# Nearest to eight:one, zero, two, nine, five, four, three, six
# Nearest to history:germanisation, th, grecian, annales, darwinism, sherborne, lia, science
# Nearest to in:the, of, and, a, with, first, between, by
# Nearest to who:yoshitaka, offeror, retained, aegisthus, trinkets, villa, whereby, cried
# Nearest to two:one, three, zero, six, five, eight, four, nine
# Nearest to all:that, of, coerced, product, rotates, set, weak, resilient
# Nearest to placed:tip, caria, structure, volusia, buffering, newman, reproduces, cabling
# Nearest to question:providential, expresses, goes, negation, answer, pythagorean, manipulating, wct
# Nearest to versions:unquestioning, trainer, lehrer, subiaco, xx, developers, levers, superhero
# Nearest to defense:macanese, sanity, parachute, harrier, extradition, pu, durst, discharging
# Nearest to pressure:donating, thee, mass, explosions, pleasuredome, conditioner, alekseyevich, litres
# Nearest to governor:branch, presides, gatherers, steamer, appointments, edvac, congress, redmond
# Nearest to san:jose, santa, croix, administered, hayao, alameda, arma, dior
# Nearest to heavy:odham, helping, blasting, electronically, percussive, liquid, kabuki, sundanese
# Epoch 5/12 Iteration: 22100 Avg. Training loss: 3.9554 0.0486 sec/batch
# Epoch 5/12 Iteration: 22200 Avg. Training loss: 4.0510 0.0477 sec/batch
# Epoch 5/12 Iteration: 22300 Avg. Training loss: 3.9856 0.0477 sec/batch
# Epoch 5/12 Iteration: 22400 Avg. Training loss: 3.9763 0.0479 sec/batch
# Epoch 5/12 Iteration: 22500 Avg. Training loss: 3.8975 0.0473 sec/batch
# Epoch 5/12 Iteration: 22600 Avg. Training loss: 3.9137 0.0475 sec/batch
# Epoch 5/12 Iteration: 22700 Avg. Training loss: 3.9283 0.0474 sec/batch
# Epoch 5/12 Iteration: 22800 Avg. Training loss: 3.8738 0.0473 sec/batch
# Epoch 5/12 Iteration: 22900 Avg. Training loss: 3.9352 0.0478 sec/batch
# Epoch 5/12 Iteration: 23000 Avg. Training loss: 3.9281 0.0474 sec/batch
# Nearest to between:the, in, surround, levitical, goeldi, statistic, anabaptism, shifting
# Nearest to however:be, ignition, porpoises, consenting, electing, than, publicity, bokuto
# Nearest to eight:one, zero, two, nine, five, six, four, three
# Nearest to history:germanisation, th, grecian, annales, see, lia, berk, darwinism
# Nearest to in:the, of, and, a, first, with, was, uncompleted
# Nearest to who:yoshitaka, jstor, offeror, aegisthus, retained, villa, cried, freas
# ...
# Epoch 11/12 Iteration: 47400 Avg. Training loss: 3.6797 0.0474 sec/batch
# Epoch 11/12 Iteration: 47500 Avg. Training loss: 3.7033 0.0475 sec/batch
# Epoch 11/12 Iteration: 47600 Avg. Training loss: 3.7719 0.0473 sec/batch
# Epoch 11/12 Iteration: 47700 Avg. Training loss: 3.6258 0.0476 sec/batch
# Epoch 11/12 Iteration: 47800 Avg. Training loss: 3.7527 0.0474 sec/batch
# Epoch 11/12 Iteration: 47900 Avg. Training loss: 3.8081 0.0474 sec/batch
# Epoch 11/12 Iteration: 48000 Avg. Training loss: 3.7644 0.0475 sec/batch
# Nearest to between:the, in, with, and, relationship, notably, together, stretches
# Nearest to however:the, their, be, of, that, though, more, which
# Nearest to eight:one, six, zero, five, three, two, nine, four
# Nearest to history:article, see, external, th, on, timeline, links, the
# Nearest to in:the, and, of, a, is, with, first, by
# Nearest to who:them, whereby, abraham, labs, yoshitaka, seeks, headship, aegisthus
# Nearest to two:one, three, zero, five, four, six, eight, nine
# Nearest to all:that, are, in, of, some, which, be, and
# Nearest to placed:placement, order, blot, second, strap, newman, cronquist, declined
# Nearest to question:answer, problem, priscilla, answers, abelard, inefficiency, answered, negation
# Nearest to versions:standard, xx, leech, lehrer, cropped, prerelease, trainer, version
# Nearest to defense:defenses, haganah, defence, air, durst, accomplish, extradition, sanity
# Nearest to pressure:heat, buboes, cooled, aversion, vibrations, heart, alekseyevich, thee
# Nearest to governor:arnold, branch, gatherers, jars, senate, governorates, steamer, obama
# Nearest to san:jose, francisco, arma, los, california, alameda, santa, bolognini
# Nearest to heavy:gassendi, tactics, electronically, helping, sundanese, rehab, flintlock, rosary
# Epoch 11/12 Iteration: 48100 Avg. Training loss: 3.7397 0.0482 sec/batch
# Epoch 11/12 Iteration: 48200 Avg. Training loss: 3.8110 0.0474 sec/batch
# Epoch 11/12 Iteration: 48300 Avg. Training loss: 3.7976 0.0474 sec/batch
# Epoch 11/12 Iteration: 48400 Avg. Training loss: 3.7322 0.0471 sec/batch
# Epoch 11/12 Iteration: 48500 Avg. Training loss: 3.7369 0.0475 sec/batch
# Epoch 11/12 Iteration: 48600 Avg. Training loss: 3.7821 0.0473 sec/batch
# Epoch 11/12 Iteration: 48700 Avg. Training loss: 3.8010 0.0474 sec/batch
# Epoch 11/12 Iteration: 48800 Avg. Training loss: 3.7480 0.0476 sec/batch
# Epoch 11/12 Iteration: 48900 Avg. Training loss: 3.7454 0.0473 sec/batch
# Epoch 11/12 Iteration: 49000 Avg. Training loss: 3.7928 0.0473 sec/batch
# Nearest to between:in, the, and, with, relationship, notably, shared, shifting
# Nearest to however:the, be, their, of, that, is, though, which
# Nearest to eight:one, six, two, nine, three, zero, four, five
# Nearest to history:see, article, external, on, links, timeline, th, of
# Nearest to in:the, and, a, of, is, first, which, with
# Nearest to who:them, whereby, yoshitaka, abraham, ioc, headship, seeks, martial
# Nearest to two:one, zero, three, five, four, six, eight, nine
# Nearest to all:some, in, that, are, of, and, which, is
# Nearest to placed:placement, second, blot, order, strap, redirecting, newman, deceased
# Nearest to question:answer, priscilla, problem, answers, abelard, negation, questions, providential
# Nearest to versions:standard, xx, leech, lehrer, version, reworked, cropped, zwicker
# Nearest to defense:defenses, air, defence, haganah, extradition, accomplish, durst, macanese
# Nearest to pressure:heat, buboes, cooled, alekseyevich, thee, aversion, vibrations, scar
# Nearest to governor:senate, appointed, branch, arnold, gatherers, obama, advice, steamer
# Nearest to san:jose, francisco, los, arma, california, santa, alameda, ashbury
# Nearest to heavy:gassendi, borrow, electronically, rehab, helping, sundanese, extensional, tactics
# Epoch 11/12 Iteration: 49100 Avg. Training loss: 3.7662 0.0487 sec/batch
# Epoch 11/12 Iteration: 49200 Avg. Training loss: 3.8062 0.0476 sec/batch
# Epoch 11/12 Iteration: 49300 Avg. Training loss: 3.7606 0.0477 sec/batch
# Epoch 11/12 Iteration: 49400 Avg. Training loss: 3.7830 0.0475 sec/batch
# Epoch 11/12 Iteration: 49500 Avg. Training loss: 3.7352 0.0479 sec/batch
# Epoch 11/12 Iteration: 49600 Avg. Training loss: 3.7350 0.0477 sec/batch
# Epoch 11/12 Iteration: 49700 Avg. Training loss: 3.7754 0.0476 sec/batch
# Epoch 11/12 Iteration: 49800 Avg. Training loss: 3.7806 0.0476 sec/batch
# Epoch 11/12 Iteration: 49900 Avg. Training loss: 3.8471 0.0475 sec/batch
# Epoch 11/12 Iteration: 50000 Avg. Training loss: 3.8388 0.0476 sec/batch
# Nearest to between:the, and, in, with, relationship, shared, notably, evictions
# Nearest to however:the, that, be, which, their, though, of, all
# Nearest to eight:one, six, two, three, zero, nine, four, five
# Nearest to history:see, article, external, on, th, timeline, links, germanisation
# Nearest to in:the, a, and, of, is, first, as, which
# Nearest to who:them, to, yoshitaka, whereby, labs, abraham, astonished, surname
# Nearest to two:one, zero, three, five, four, six, eight, nine
# Nearest to all:some, that, are, in, of, which, and, even
# Nearest to placed:placement, second, order, declined, blot, endl, newman, replenished
# Nearest to question:answer, priscilla, answers, problem, abelard, questions, partei, negation
# Nearest to versions:standard, leech, xx, lehrer, castaneda, reworked, zwicker, prerelease
# Nearest to defense:defenses, defence, haganah, extradition, air, durst, accomplish, yerushalmi
# Nearest to pressure:buboes, cooled, aversion, heat, vibrations, scar, alekseyevich, glottal
# Nearest to governor:arnold, obama, senate, gatherers, steamer, appointed, branch, advice
# Nearest to san:jose, francisco, arma, los, santa, california, alameda, ashbury
# Nearest to heavy:gassendi, electronically, borrow, rehab, sundanese, helping, tactics, metal
# Epoch 11/12 Iteration: 50100 Avg. Training loss: 3.8085 0.0485 sec/batch
# Epoch 11/12 Iteration: 50200 Avg. Training loss: 3.7772 0.0475 sec/batch
# Epoch 11/12 Iteration: 50300 Avg. Training loss: 3.6994 0.0474 sec/batch
# Epoch 11/12 Iteration: 50400 Avg. Training loss: 3.7528 0.0475 sec/batch
# Epoch 11/12 Iteration: 50500 Avg. Training loss: 3.6558 0.0474 sec/batch
# Epoch 11/12 Iteration: 50600 Avg. Training loss: 3.7757 0.0475 sec/batch
# Epoch 11/12 Iteration: 50700 Avg. Training loss: 3.7647 0.0475 sec/batch
# Epoch 11/12 Iteration: 50800 Avg. Training loss: 3.7701 0.0474 sec/batch
# Epoch 12/12 Iteration: 50900 Avg. Training loss: 3.7947 0.0070 sec/batch
# Epoch 12/12 Iteration: 51000 Avg. Training loss: 3.7733 0.0472 sec/batch
# Nearest to between:the, in, with, and, relationship, notably, of, shifting
# Nearest to however:the, that, be, which, their, to, all, of
# Nearest to eight:one, six, nine, two, three, zero, four, seven
# Nearest to history:see, article, external, on, timeline, th, links, germanisation
# Nearest to in:the, and, a, of, with, as, is, first
# Nearest to who:them, whereby, astonished, yoshitaka, labs, martial, abraham, delores
# Nearest to two:one, zero, three, five, four, six, eight, nine
# Nearest to all:some, like, in, are, that, which, more, the
# Nearest to placed:second, placement, order, blot, strap, newman, declined, structure
# Nearest to question:answer, answers, priscilla, problem, questions, abelard, ghq, answered
# Nearest to versions:standard, xx, leech, version, reworked, lehrer, developers, prerelease
# Nearest to defense:defenses, defence, haganah, durst, accomplish, extradition, air, sanity
# Nearest to pressure:aversion, scar, cooled, heat, buboes, alekseyevich, glottal, kilowatt
# Nearest to governor:arnold, gatherers, obama, steamer, appointed, branch, senate, advice
# Nearest to san:francisco, jose, los, arma, california, alameda, ashbury, santa
# Nearest to heavy:gassendi, electronically, borrow, rehab, metal, troad, sundanese, fan
# Epoch 12/12 Iteration: 51100 Avg. Training loss: 3.7308 0.0486 sec/batch
# Epoch 12/12 Iteration: 51200 Avg. Training loss: 3.7336 0.0476 sec/batch
# Epoch 12/12 Iteration: 51300 Avg. Training loss: 3.7628 0.0477 sec/batch
# Epoch 12/12 Iteration: 51400 Avg. Training loss: 3.7117 0.0473 sec/batch
# Epoch 12/12 Iteration: 51500 Avg. Training loss: 3.7422 0.0475 sec/batch
# Epoch 12/12 Iteration: 51600 Avg. Training loss: 3.7180 0.0477 sec/batch
# Epoch 12/12 Iteration: 51700 Avg. Training loss: 3.7450 0.0472 sec/batch
# Epoch 12/12 Iteration: 51800 Avg. Training loss: 3.7505 0.0472 sec/batch
# Epoch 12/12 Iteration: 51900 Avg. Training loss: 3.7737 0.0474 sec/batch
# Epoch 12/12 Iteration: 52000 Avg. Training loss: 3.7179 0.0472 sec/batch
# Nearest to between:with, in, the, and, relationship, notably, of, shared
# Nearest to however:the, of, their, that, which, to, be, all
# Nearest to eight:one, six, zero, three, nine, two, four, five
# Nearest to history:see, article, external, links, on, th, timeline, term
# Nearest to in:the, and, a, of, which, with, is, first
# Nearest to who:them, to, whereby, not, abraham, labs, delores, astonished
# Nearest to two:one, three, five, zero, four, six, eight, nine
# Nearest to all:some, in, the, that, which, are, and, a
# Nearest to placed:second, order, placement, declined, strap, newman, deceased, blot
# Nearest to question:answer, answers, priscilla, abelard, problem, questions, answered, partei
# Nearest to versions:standard, xx, leech, lehrer, reworked, version, prerelease, castaneda
# Nearest to defense:defenses, defence, haganah, extradition, durst, accomplish, air, frosts
# Nearest to pressure:aversion, heat, buboes, kilowatt, cooled, scar, glottal, alekseyevich
# Nearest to governor:arnold, appointed, gatherers, senate, branch, advice, governorates, obama
# Nearest to san:francisco, jose, los, california, alameda, arma, santa, ashbury
# Nearest to heavy:gassendi, electronically, metal, borrow, rehab, helping, flintlock, fulci
# Epoch 12/12 Iteration: 52100 Avg. Training loss: 3.6934 0.0484 sec/batch
# Epoch 12/12 Iteration: 52200 Avg. Training loss: 3.7135 0.0472 sec/batch
# Epoch 12/12 Iteration: 52300 Avg. Training loss: 3.6462 0.0476 sec/batch
# Epoch 12/12 Iteration: 52400 Avg. Training loss: 3.7209 0.0473 sec/batch
# Epoch 12/12 Iteration: 52500 Avg. Training loss: 3.7314 0.0473 sec/batch
# Epoch 12/12 Iteration: 52600 Avg. Training loss: 3.7335 0.0473 sec/batch
# Epoch 12/12 Iteration: 52700 Avg. Training loss: 3.7343 0.0474 sec/batch
# Epoch 12/12 Iteration: 52800 Avg. Training loss: 3.7949 0.0476 sec/batch
# Epoch 12/12 Iteration: 52900 Avg. Training loss: 3.7487 0.0472 sec/batch
# Epoch 12/12 Iteration: 53000 Avg. Training loss: 3.7104 0.0471 sec/batch
# Nearest to between:in, with, and, the, relationship, notably, shared, through
# Nearest to however:the, that, their, be, which, all, of, as
# Nearest to eight:one, six, nine, three, zero, two, four, five
# Nearest to history:see, article, external, links, on, timeline, th, the
# Nearest to in:the, and, a, of, with, which, is, first
# Nearest to who:them, labs, even, seeks, abraham, whereby, delores, yoshitaka
# Nearest to two:one, three, zero, five, four, six, eight, nine
# Nearest to all:that, some, are, which, in, other, and, of
# Nearest to placed:second, order, placement, declined, deceased, blot, newman, instead
# Nearest to question:answer, problem, answers, priscilla, abelard, questions, negation, arisen
# Nearest to versions:xx, standard, leech, lehrer, reworked, version, omits, bile
# Nearest to defense:defence, defenses, accomplish, haganah, extradition, air, durst, sanity
# Nearest to pressure:buboes, cooled, heart, heat, aversion, condenser, vibrations, glottal
# Nearest to governor:gatherers, arnold, appointed, governorates, branch, senate, obama, advice
# Nearest to san:francisco, jose, los, california, alameda, arma, santa, ashbury
# Nearest to heavy:gassendi, electronically, borrow, tcs, ytterbium, katy, metal, fulci
# Epoch 12/12 Iteration: 53100 Avg. Training loss: 3.7572 0.0485 sec/batch
# Epoch 12/12 Iteration: 53200 Avg. Training loss: 3.7692 0.0474 sec/batch
# Epoch 12/12 Iteration: 53300 Avg. Training loss: 3.7394 0.0474 sec/batch
# Epoch 12/12 Iteration: 53400 Avg. Training loss: 3.7233 0.0474 sec/batch
# Epoch 12/12 Iteration: 53500 Avg. Training loss: 3.7512 0.0473 sec/batch
# Epoch 12/12 Iteration: 53600 Avg. Training loss: 3.7622 0.0475 sec/batch
# Epoch 12/12 Iteration: 53700 Avg. Training loss: 3.7286 0.0476 sec/batch
# Epoch 12/12 Iteration: 53800 Avg. Training loss: 3.7740 0.0474 sec/batch
# Epoch 12/12 Iteration: 53900 Avg. Training loss: 3.7549 0.0473 sec/batch
# Epoch 12/12 Iteration: 54000 Avg. Training loss: 3.7732 0.0471 sec/batch
# Nearest to between:in, and, the, with, relationship, notably, of, shifting
# Nearest to however:the, of, which, that, though, to, be, their
# Nearest to eight:one, six, nine, three, four, two, zero, five
# Nearest to history:see, article, external, timeline, links, on, germanisation, the
# Nearest to in:the, and, a, of, which, with, was, by
# Nearest to who:them, to, yoshitaka, even, from, whereby, headship, abraham
# Nearest to two:one, three, zero, five, four, six, eight, nine
# Nearest to all:some, in, are, and, which, of, the, that
# Nearest to placed:second, order, placement, deceased, declined, blot, newman, instead
# Nearest to question:answer, priscilla, problem, answers, abelard, questions, answered, arisen
# Nearest to versions:standard, xx, leech, version, reworked, lehrer, castaneda, bile
# Nearest to defense:defence, defenses, air, extradition, accomplish, haganah, durst, sanity
# Nearest to pressure:aversion, scar, glottal, buboes, heat, alekseyevich, vibrations, heart
# Nearest to governor:gatherers, appointed, arnold, senate, governorates, obama, advice, rojcewicz
# Nearest to san:francisco, jose, los, california, ashbury, santa, alameda, antonio
# Nearest to heavy:gassendi, metal, electronically, rehab, fan, borrow, adaptability, fenrir
# Epoch 12/12 Iteration: 54100 Avg. Training loss: 3.7157 0.0486 sec/batch
# Epoch 12/12 Iteration: 54200 Avg. Training loss: 3.7100 0.0474 sec/batch
# Epoch 12/12 Iteration: 54300 Avg. Training loss: 3.6895 0.0472 sec/batch
# Epoch 12/12 Iteration: 54400 Avg. Training loss: 3.8285 0.0475 sec/batch
# Epoch 12/12 Iteration: 54500 Avg. Training loss: 3.7759 0.0474 sec/batch
# Epoch 12/12 Iteration: 54600 Avg. Training loss: 3.8431 0.0474 sec/batch
# Epoch 12/12 Iteration: 54700 Avg. Training loss: 3.8091 0.0474 sec/batch
# Epoch 12/12 Iteration: 54800 Avg. Training loss: 3.7330 0.0476 sec/batch
# Epoch 12/12 Iteration: 54900 Avg. Training loss: 3.7045 0.0472 sec/batch
# Epoch 12/12 Iteration: 55000 Avg. Training loss: 3.7037 0.0474 sec/batch
# Nearest to between:the, in, and, with, relationship, notably, control, shifting
# Nearest to however:the, that, large, which, be, though, their, particularly
# Nearest to eight:one, six, nine, zero, three, two, four, five
# Nearest to history:see, article, external, timeline, links, on, germanisation, th
# Nearest to in:the, a, of, and, which, with, as, by
# Nearest to who:them, abraham, labs, astonished, tagore, surname, delores, whereby
# Nearest to two:one, zero, three, five, four, six, eight, nine
# Nearest to all:some, are, the, that, in, more, which, of
# Nearest to placed:second, placement, order, blot, deceased, strap, declined, newman
# Nearest to question:answer, priscilla, questions, answers, problem, abelard, answered, inefficiency
# Nearest to versions:standard, xx, leech, bile, lehrer, reworked, castaneda, omits
# Nearest to defense:defence, defenses, haganah, accomplish, extradition, air, sanity, yerushalmi
# Nearest to pressure:aversion, cooled, heat, scar, buboes, tailplane, electrotechnical, vibrations
# Nearest to governor:appointed, arnold, gatherers, senate, governorates, obama, civilized, advisers
# Nearest to san:francisco, jose, los, california, santa, antonio, ashbury, arma
# Nearest to heavy:gassendi, rehab, fan, borrow, adaptability, fenrir, troad, helping
# Epoch 12/12 Iteration: 55100 Avg. Training loss: 3.6885 0.0485 sec/batch
# Epoch 12/12 Iteration: 55200 Avg. Training loss: 3.7320 0.0474 sec/batch
# Epoch 12/12 Iteration: 55300 Avg. Training loss: 3.7366 0.0474 sec/batch
# Epoch 12/12 Iteration: 55400 Avg. Training loss: 3.7242 0.0475 sec/batch
# Epoch 12/12 Iteration: 55500 Avg. Training loss: 3.7640 0.0476 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
5
# Out:
# 5

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#
# /home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#
# /home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      88             try:
# ---> 89                 next(self.gen)
#      90             except StopIteration:
#
# /home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# InvalidArgumentError: Assign requires shapes of both tensors to match. lhs shape= [63641,200] rhs shape= [63641,300]
# 	 [[Node: save/Assign_5 = Assign[T=DT_FLOAT, _class=["loc:@Variable_1"], use_locking=true, validate_shape=true, _device="/job:localhost/replica:0/task:0/cpu:0"](Variable_1/Adam_1, save/RestoreV2_5)]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-20-4eeca6a379f0> in <module>()
#       3
#       4 with tf.Session(graph=train_graph) as sess:
# ----> 5     saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
#       6     embed_mat = sess.run(embedding)
#
# /home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1426       return
#    1427     sess.run(self.saver_def.restore_op_name,
# -> 1428              {self.saver_def.filename_tensor_name: save_path})
#    1429
#    1430   @staticmethod
#
# /home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# InvalidArgumentError: Assign requires shapes of both tensors to match. lhs shape= [63641,200] rhs shape= [63641,300]
# 	 [[Node: save/Assign_5 = Assign[T=DT_FLOAT, _class=["loc:@Variable_1"], use_locking=true, validate_shape=true, _device="/job:localhost/replica:0/task:0/cpu:0"](Variable_1/Adam_1, save/RestoreV2_5)]]
#
# Caused by op 'save/Assign_5', defined at:
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-20-4eeca6a379f0>", line 2, in <module>
#     saver = tf.train.Saver()
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1040, in __init__
#     self.build()
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1070, in build
#     restore_sequentially=self._restore_sequentially)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 675, in build
#     restore_sequentially, reshape)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 414, in _AddRestoreOps
#     assign_ops.append(saveable.restore(tensors, shapes))
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 155, in restore
#     self.op.get_shape().is_fully_defined())
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/ops/gen_state_ops.py", line 47, in assign
#     use_locking=use_locking, name=name)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2327, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/home/ACCELEWARE/scott.quiring/.conda/envs/dlr7/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1226, in __init__
#     self._traceback = _extract_stack()
#
# InvalidArgumentError (see above for traceback): Assign requires shapes of both tensors to match. lhs shape= [63641,200] rhs shape= [63641,300]
# 	 [[Node: save/Assign_5 = Assign[T=DT_FLOAT, _class=["loc:@Variable_1"], use_locking=true, validate_shape=true, _device="/job:localhost/replica:0/task:0/cpu:0"](Variable_1/Adam_1, save/RestoreV2_5)]]

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %%
def word_difference(a,b):
    word_a = embed_mat[vocab_to_int[a],:]
    word_b = embed_mat[vocab_to_int[b],:]
    return word_b - word_a

# %%
kq = word_difference('king', 'queen')

# %%
pp = word_difference('prince', 'princess')

# %%
def cosine_similarity(a,b):
    return np.dot(a,b) / np.sqrt(np.sum(np.square(a)) + np.sum(np.square(b)))

# %%
cosine_similarity(kq,pp)
# Out:
# 0.0015999459

# %%
def analogy(a,b,A,B=None):
    if B is None:
        best_word = -1
        best_diff = -1
        ab = word_difference(a,b)
        idx_b = vocab_to_int[b]
        word_A = embed_mat[vocab_to_int[A],:]
        for i in int_to_vocab.keys():
            word_B = embed_mat[i,:]
            AB = cosine_similarity(ab, word_B - word_A)
            if AB > best_diff and i != idx_b:
                best_diff = AB
                best_word = i
        return (int_to_vocab[best_word], best_diff)
    else:
        ab = word_difference(a,b)
        AB = word_difference(A,B)
        return cosine_similarity(ab,AB)

# %%
def analogy(a,b,c):
    input_idxs = tuple([vocab_to_int[i] for i in [a,b,c]])
    diff = embed_mat[vocab_to_int[b],:] - embed_mat[vocab_to_int[a],:]
    d_embed = embed_mat[vocab_to_int[c],:] + diff
    
    closest_word = -1
    closest_error = np.inf
    
    for i in int_to_vocab.keys():
        error = np.sqrt(np.sum(np.square(embed_mat[i,:] - d_embed)))
        if error < closest_error and i not in input_idxs:
            closest_word = i
            closest_error = error
    
    return (int_to_vocab[closest_word], closest_error)

# %%
analogy('man', 'woman', 'men')
# Out:
# ('women', 1.4388856)

# %%
analogy('better','best', 'worse')
# Out:
# ('satara', 1.6486371)

# %%
analogy('his','her','he')
# Out:
# ('she', 1.2619072)

# %%
analogy('east','west','north')
# Out:
# ('south', 1.3838494)

# %%
analogy('force', 'forces', 'book')
# Out:
# ('vigilance', 1.5039809)

# %%
analogy('man','woman','he')
# Out:
# ('salaino', 1.5708857)

# %%
analogy('france','paris','spain')
# Out:
# ('bogot', 1.4455863)

# %%
analogy('france','french','japan')
# Out:
# ('japanese', 1.3163509)

# %%
analogy('japan','japanese','china')
# Out:
# ('han', 1.4620105)

# %%
analogy('france','french','canada')
# Out:
# ('canadian', 1.4493972)

# %%
analogy('france','french','spain')
# Out:
# ('morons', 1.4011776)

# %%
analogy('')
# Out:
# ('siqueiros', 1.7109681)
