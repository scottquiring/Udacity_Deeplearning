# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
np.random.random()

from collections import Counter

# %%
word_counts = Counter(int_words)

# %%
threshold = 1e-5

def word_frequency(word):
    return word_counts[word] / len(int_words)

def word_probability(word, threshold):
    return 1.0 - np.sqrt(threshold / word_frequency(word))

word_probabilities = {w: word_probability(w, threshold) for w in int_to_vocab.keys()}

# %%
train_words = [w for w in int_words if word_probabilities[w] < np.random.random()]

# %%
word_probabilities[vocab_to_int['hero']]
# Out:
# 0.52996267585146473

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = np.random.randint(1,window_size+1)
    minIdx = max(idx-r,0)
    maxIdx = min(idx+r+1,len(words))
    return words[minIdx:idx] + words[idx+1:maxIdx]

# %%
train_words[4627032:4627031]
#len(train_words)
# Out:
# []

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding), -1,1))
    embed = tf.nn.embedding_lookup(embedding, inputs)
    # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b,
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']
# Out:
# '0'

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 12
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    log += ', '.join([int_to_vocab[nearest[k]] for k in range(top_k)])
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/12 Iteration: 100 Avg. Training loss: 5.6210 0.0711 sec/batch
# Epoch 1/12 Iteration: 200 Avg. Training loss: 5.5974 0.0686 sec/batch
# Epoch 1/12 Iteration: 300 Avg. Training loss: 5.4740 0.0687 sec/batch
# Epoch 1/12 Iteration: 400 Avg. Training loss: 5.5883 0.0680 sec/batch
# Epoch 1/12 Iteration: 500 Avg. Training loss: 5.4405 0.0693 sec/batch
# Epoch 1/12 Iteration: 600 Avg. Training loss: 5.4703 0.0689 sec/batch
# Epoch 1/12 Iteration: 700 Avg. Training loss: 5.5100 0.0696 sec/batch
# Epoch 1/12 Iteration: 800 Avg. Training loss: 5.4913 0.0691 sec/batch
# Epoch 1/12 Iteration: 900 Avg. Training loss: 5.4352 0.0683 sec/batch
# Epoch 1/12 Iteration: 1000 Avg. Training loss: 5.3744 0.0690 sec/batch
# Nearest to over:avoidance, ampersand, liza, sector, bullseye, allergen, lighters, exterminate
# Nearest to only:rutgers, deprive, caml, shooter, cheesemaking, direct, noronha, famed
# Nearest to also:basie, unfounded, semitism, panth, pianos, shaw, catch, tracing
# Nearest to not:rembrandt, ribald, cedi, favouring, well, seaports, spake, garde
# Nearest to which:helicopter, stewardship, laconia, score, cach, opium, knowledge, hinds
# Nearest to more:rafters, voight, speciesism, treatments, kourou, radclyffe, cordon, collides
# Nearest to there:alves, vee, expelled, abolition, tiresias, longer, cryptographer, ssbauer
# Nearest to the:nanometres, genie, pau, alde, bowling, tribesman, definitively, farmer
# Nearest to powers:balladeer, protectorates, macaroni, petition, commands, vipassana, agar, travels
# Nearest to accepted:prussians, revolver, fantasyland, silenced, right, tobacco, monasticism, polaris
# Nearest to arts:differentials, womanizer, fluorescent, nafs, pdl, pathogen, disintegrating, clusters
# Nearest to instance:dilates, porco, saved, weekdays, diffusing, shotgun, wehrmacht, samsara
# Nearest to cost:binitarianism, nuit, herons, universalists, lattices, porritt, pelvis, memex
# Nearest to ice:overworld, fastball, longman, watercolor, isospin, analyzes, booking, cans
# Nearest to pressure:ned, heuristics, alessandri, thorpe, microfibrils, propped, ignore, abstaining
# Nearest to assembly:lcms, stimulating, astronaut, deco, takamine, waltzing, wikipedian, akshara
# Epoch 1/12 Iteration: 1100 Avg. Training loss: 5.4476 0.0697 sec/batch
# Epoch 1/12 Iteration: 1200 Avg. Training loss: 5.3920 0.0685 sec/batch
# Epoch 1/12 Iteration: 1300 Avg. Training loss: 5.3341 0.0688 sec/batch
# Epoch 1/12 Iteration: 1400 Avg. Training loss: 5.2346 0.0692 sec/batch
# Epoch 1/12 Iteration: 1500 Avg. Training loss: 5.1850 0.0687 sec/batch
# Epoch 1/12 Iteration: 1600 Avg. Training loss: 5.1679 0.0687 sec/batch
# Epoch 1/12 Iteration: 1700 Avg. Training loss: 5.1468 0.0688 sec/batch
# Epoch 1/12 Iteration: 1800 Avg. Training loss: 5.0954 0.0687 sec/batch
# Epoch 1/12 Iteration: 1900 Avg. Training loss: 4.9940 0.0678 sec/batch
# Epoch 1/12 Iteration: 2000 Avg. Training loss: 4.9902 0.0704 sec/batch
# Nearest to over:sector, into, avoidance, welfare, liza, among, duress, course
# Nearest to only:direct, rutgers, shooter, anything, dinner, teachers, caml, famed
# Nearest to also:basie, catch, semitism, pianos, presentation, colour, tracing, shaw
# Nearest to not:well, yet, seaports, favouring, rembrandt, button, ribald, spake
# Nearest to which:score, photons, knowledge, helicopter, civilian, vanes, didius, overview
# Nearest to more:define, frozen, extensive, treatments, senators, argued, recipe, speciesism
# Nearest to there:longer, point, vee, n, alves, commuter, argued, expelled
# Nearest to the:nanometres, definitively, genie, controversial, farmer, alde, deriving, son
# Nearest to powers:commands, petition, balladeer, macaroni, protectorates, occupied, accord, travels
# Nearest to accepted:right, capable, prussians, tobacco, revolver, mainstream, simple, suspicion
# Nearest to arts:fluorescent, differentials, womanizer, pdl, nafs, clusters, journeys, marked
# Nearest to instance:saved, diffusing, weekdays, dilates, thus, facet, contraindications, uniting
# Nearest to cost:herons, nuit, binitarianism, lattices, universalists, shops, fis, adopting
# Nearest to ice:overworld, longman, multi, watercolor, fastball, calculated, steady, cans
# Nearest to pressure:ned, ignore, alessandri, environment, poverty, implicitly, handbook, seems
# Nearest to assembly:stimulating, takamine, akshara, sforza, deco, autostrada, waltzing, wikipedian
# Epoch 1/12 Iteration: 2100 Avg. Training loss: 4.9576 0.0704 sec/batch
# Epoch 1/12 Iteration: 2200 Avg. Training loss: 4.9046 0.0684 sec/batch
# Epoch 1/12 Iteration: 2300 Avg. Training loss: 4.8728 0.0685 sec/batch
# Epoch 1/12 Iteration: 2400 Avg. Training loss: 4.8645 0.0687 sec/batch
# Epoch 1/12 Iteration: 2500 Avg. Training loss: 4.8208 0.0681 sec/batch
# Epoch 1/12 Iteration: 2600 Avg. Training loss: 4.8234 0.0690 sec/batch
# Epoch 1/12 Iteration: 2700 Avg. Training loss: 4.7970 0.0686 sec/batch
# Epoch 1/12 Iteration: 2800 Avg. Training loss: 4.7978 0.0676 sec/batch
# Epoch 1/12 Iteration: 2900 Avg. Training loss: 4.7719 0.0690 sec/batch
# Epoch 1/12 Iteration: 3000 Avg. Training loss: 4.7985 0.0689 sec/batch
# Nearest to over:sector, avoidance, welfare, into, bullseye, ampersand, exterminate, joe
# Nearest to only:rutgers, direct, shooter, anything, deprive, dinner, caml, teachers
# Nearest to also:basie, semitism, unfounded, shaw, catch, pianos, tracing, heading
# Nearest to not:favouring, seaports, cedi, well, button, rembrandt, ribald, promises
# Nearest to which:score, helicopter, photons, knowledge, civilian, nominally, didius, overview
# Nearest to more:treatments, define, senators, kourou, extensive, sovereign, recipe, fractures
# Nearest to there:longer, abolition, vee, point, expelled, alves, hemisphere, sworn
# Nearest to the:nanometres, definitively, controversial, deriving, genie, alde, adjusting, churchill
# Nearest to powers:commands, petition, travels, accord, balladeer, democrats, crowns, protectorates
# Nearest to accepted:right, prussians, tobacco, revolver, monasticism, capable, mississippi, fantasyland
# Nearest to arts:differentials, fluorescent, womanizer, pdl, junior, clusters, klaus, nafs
# Nearest to instance:diffusing, saved, thus, facet, deutsche, weekdays, uniting, denote
# Nearest to cost:herons, binitarianism, nuit, lattices, possessive, shops, fis, adopting
# Nearest to ice:multi, calculated, overworld, steady, watercolor, longman, plug, cans
# Nearest to pressure:ned, ignore, alessandri, implicitly, aborted, heuristics, environment, poverty
# Nearest to assembly:takamine, stimulating, shade, dame, pseudo, autostrada, colored, wikipedian
# Epoch 1/12 Iteration: 3100 Avg. Training loss: 4.7883 0.0682 sec/batch
# Epoch 1/12 Iteration: 3200 Avg. Training loss: 4.7481 0.0681 sec/batch
# Epoch 1/12 Iteration: 3300 Avg. Training loss: 4.7258 0.0691 sec/batch
# Epoch 1/12 Iteration: 3400 Avg. Training loss: 4.7280 0.0677 sec/batch
# Epoch 1/12 Iteration: 3500 Avg. Training loss: 4.7329 0.0677 sec/batch
# Epoch 1/12 Iteration: 3600 Avg. Training loss: 4.7129 0.0678 sec/batch
# Epoch 1/12 Iteration: 3700 Avg. Training loss: 4.7112 0.0683 sec/batch
# Epoch 1/12 Iteration: 3800 Avg. Training loss: 4.7494 0.0685 sec/batch
# Epoch 1/12 Iteration: 3900 Avg. Training loss: 4.6920 0.0694 sec/batch
# Epoch 1/12 Iteration: 4000 Avg. Training loss: 4.6660 0.0678 sec/batch
# Nearest to over:sector, avoidance, welfare, into, ampersand, exterminate, joe, liza
# Nearest to only:rutgers, direct, deprive, cheesemaking, encounter, anything, shooter, woodwinds
# Nearest to also:basie, unfounded, semitism, pianos, panth, tracing, shaw, catch
# Nearest to not:ribald, cedi, seaports, button, well, yet, favouring, notebook
# Nearest to which:score, knowledge, helicopter, photons, nominally, civilian, overview, opium
# Nearest to more:treatments, define, collides, senators, extensive, voight, fractures, kourou
# Nearest to there:longer, probabilistic, vee, abolition, point, argued, sworn, alves
# Nearest to the:nanometres, controversial, adjusting, gust, willingly, tribesman, alde, genie
# Nearest to powers:commands, balladeer, petition, protectorates, crowns, accord, democrats, travels
# Nearest to accepted:prussians, tobacco, revolver, right, silenced, monasticism, polaris, fantasyland
# Nearest to arts:differentials, fluorescent, junior, pdl, clusters, klaus, womanizer, expires
# Nearest to instance:diffusing, thus, saved, facet, weekdays, uniting, denote, enjoys
# Nearest to cost:herons, binitarianism, nuit, porritt, fis, lattices, reece, shops
# Nearest to ice:overworld, steady, watercolor, multi, longman, isospin, calculated, booking
# Nearest to pressure:ned, ignore, heuristics, anson, implicitly, arthurian, alessandri, vedic
# Nearest to assembly:wikipedian, takamine, pseudo, stimulating, deco, mainstay, shade, astronaut
# Epoch 1/12 Iteration: 4100 Avg. Training loss: 4.6703 0.0700 sec/batch
# Epoch 1/12 Iteration: 4200 Avg. Training loss: 4.6846 0.0687 sec/batch
# Epoch 1/12 Iteration: 4300 Avg. Training loss: 4.6006 0.0683 sec/batch
# Epoch 1/12 Iteration: 4400 Avg. Training loss: 4.6374 0.0678 sec/batch
# Epoch 1/12 Iteration: 4500 Avg. Training loss: 4.6284 0.0689 sec/batch
# Epoch 1/12 Iteration: 4600 Avg. Training loss: 4.6415 0.0687 sec/batch
# Epoch 2/12 Iteration: 4700 Avg. Training loss: 4.6214 0.0504 sec/batch
# Epoch 2/12 Iteration: 4800 Avg. Training loss: 4.5742 0.0682 sec/batch
# Epoch 2/12 Iteration: 4900 Avg. Training loss: 4.5125 0.0681 sec/batch
# Epoch 2/12 Iteration: 5000 Avg. Training loss: 4.4849 0.0689 sec/batch
# Nearest to over:sector, avoidance, welfare, ampersand, into, exterminate, bullseye, delegated
# Nearest to only:rutgers, direct, deprive, cheesemaking, shooter, anything, woodwinds, caml
# Nearest to also:basie, panth, tracing, unfounded, pianos, semitism, avogadro, catch
# Nearest to not:button, yet, notebook, ribald, well, cedi, seaports, tweaking
# Nearest to which:knowledge, score, oboe, stewardship, civilian, photons, helicopter, overview
# Nearest to more:treatments, define, collides, rafters, fractures, voight, senators, kourou
# Nearest to there:longer, probabilistic, point, abolition, vee, argued, alves, less
# Nearest to the:nanometres, willingly, pau, adjusting, majestic, controversial, tribesman, brunei
# Nearest to powers:protectorates, balladeer, commands, crowns, petition, democrats, accord, macaroni
# Nearest to accepted:prussians, revolver, right, tobacco, silenced, kitsch, fantasyland, acknowledgement
# Nearest to arts:differentials, junior, pdl, clusters, klaus, cardiff, womanizer, disintegrating
# Nearest to instance:diffusing, thus, facet, saved, denote, uniting, weekdays, eschewed
# Nearest to cost:binitarianism, herons, porritt, nuit, fis, lattices, reece, chip
# Nearest to ice:overworld, isospin, steady, calculated, booking, plug, watercolor, longman
# Nearest to pressure:ned, heuristics, implicitly, aborted, anson, triads, melon, arthurian
# Nearest to assembly:deco, wikipedian, waltzing, stimulating, takamine, mainstay, pseudo, radiators
# Epoch 2/12 Iteration: 5100 Avg. Training loss: 4.4790 0.0702 sec/batch
# Epoch 2/12 Iteration: 5200 Avg. Training loss: 4.4905 0.0685 sec/batch
# Epoch 2/12 Iteration: 5300 Avg. Training loss: 4.4594 0.0684 sec/batch
# Epoch 2/12 Iteration: 5400 Avg. Training loss: 4.5152 0.0689 sec/batch
# Epoch 2/12 Iteration: 5500 Avg. Training loss: 4.4825 0.0682 sec/batch
# Epoch 2/12 Iteration: 5600 Avg. Training loss: 4.4816 0.0684 sec/batch
# Epoch 2/12 Iteration: 5700 Avg. Training loss: 4.4400 0.0673 sec/batch
# Epoch 2/12 Iteration: 5800 Avg. Training loss: 4.3818 0.0678 sec/batch
# Epoch 2/12 Iteration: 5900 Avg. Training loss: 4.4481 0.0689 sec/batch
# Epoch 2/12 Iteration: 6000 Avg. Training loss: 4.4190 0.0687 sec/batch
# Nearest to over:sector, avoidance, welfare, into, battlegroup, bullseye, ampersand, exterminate
# Nearest to only:direct, rutgers, cheesemaking, anything, deprive, metronome, shooter, woodwinds
# Nearest to also:basie, panth, tracing, avogadro, unfounded, pianos, catch, semitism
# Nearest to not:yet, cedi, button, well, ribald, experience, notebook, any
# Nearest to which:knowledge, photons, oboe, stewardship, opium, nominally, score, ofc
# Nearest to more:treatments, fractures, define, collides, rafters, recipe, extensive, voight
# Nearest to there:probabilistic, longer, point, less, vee, argued, exothermic, superstitions
# Nearest to the:nanometres, brunei, pau, adjusting, tribesman, willingly, lexeme, forests
# Nearest to powers:protectorates, balladeer, commands, democrats, accord, petition, occupied, etruria
# Nearest to accepted:prussians, revolver, right, monasticism, chemists, fantasyland, silenced, starling
# Nearest to arts:differentials, junior, pdl, klaus, cardiff, portrait, keegan, womanizer
# Nearest to instance:diffusing, saved, thus, denote, facet, eschewed, weekdays, do
# Nearest to cost:binitarianism, porritt, herons, reece, fis, lattices, nuit, chip
# Nearest to ice:steady, isospin, overworld, calculated, booking, piedmont, watercolor, chorionic
# Nearest to pressure:heuristics, implicitly, triads, microfibrils, thebaid, ned, mms, anson
# Nearest to assembly:waltzing, wikipedian, deco, pavlovich, passed, voted, supersessionism, pseudo
# Epoch 2/12 Iteration: 6100 Avg. Training loss: 4.4472 0.0703 sec/batch
# Epoch 2/12 Iteration: 6200 Avg. Training loss: 4.3956 0.0688 sec/batch
# Epoch 2/12 Iteration: 6300 Avg. Training loss: 4.4158 0.0681 sec/batch
# Epoch 2/12 Iteration: 6400 Avg. Training loss: 4.3773 0.0686 sec/batch
# Epoch 2/12 Iteration: 6500 Avg. Training loss: 4.3853 0.0694 sec/batch
# Epoch 2/12 Iteration: 6600 Avg. Training loss: 4.4241 0.0681 sec/batch
# Epoch 2/12 Iteration: 6700 Avg. Training loss: 4.3632 0.0683 sec/batch
# Epoch 2/12 Iteration: 6800 Avg. Training loss: 4.3792 0.0681 sec/batch
# Epoch 2/12 Iteration: 6900 Avg. Training loss: 4.3728 0.0681 sec/batch
# Epoch 2/12 Iteration: 7000 Avg. Training loss: 4.3555 0.0687 sec/batch
# Nearest to over:sector, avoidance, welfare, mbit, battlegroup, into, lighters, guiana
# Nearest to only:direct, cheesemaking, anything, deprive, porosity, rutgers, metronome, signifying
# Nearest to also:basie, panth, tracing, avogadro, unfounded, pianos, catch, colour
# Nearest to not:yet, any, well, without, experience, tweaking, button, reserved
# Nearest to which:knowledge, oboe, photons, stewardship, overview, score, profiting, communicable
# Nearest to more:treatments, fractures, define, kourou, fraenkel, rafters, recipe, extensive
# Nearest to there:point, probabilistic, less, longer, argued, adic, vee, exothermic
# Nearest to the:nanometres, tribesman, adjusting, a, sarcophagus, patrons, brunei, pau
# Nearest to powers:balladeer, protectorates, democrats, commands, accord, petition, occupied, crowns
# Nearest to accepted:prussians, monasticism, erv, fantasyland, revolver, right, chemists, silenced
# Nearest to arts:junior, differentials, klaus, portrait, cardiff, donahue, pdl, keegan
# Nearest to instance:diffusing, saved, thus, facet, denote, do, eschewed, uniting
# Nearest to cost:porritt, binitarianism, reece, chip, lattices, fis, herons, shops
# Nearest to ice:overworld, steady, isospin, calculated, water, plug, booking, piedmont
# Nearest to pressure:gas, triads, heuristics, implicitly, environment, mms, kinetic, microfibrils
# Nearest to assembly:waltzing, referendum, voted, deco, wikipedian, supersessionism, passed, pavlovich
# Epoch 2/12 Iteration: 7100 Avg. Training loss: 4.3761 0.0699 sec/batch
# Epoch 2/12 Iteration: 7200 Avg. Training loss: 4.3502 0.0676 sec/batch
# Epoch 2/12 Iteration: 7300 Avg. Training loss: 4.3818 0.0678 sec/batch
# Epoch 2/12 Iteration: 7400 Avg. Training loss: 4.3398 0.0683 sec/batch
# Epoch 2/12 Iteration: 7500 Avg. Training loss: 4.3793 0.0689 sec/batch
# Epoch 2/12 Iteration: 7600 Avg. Training loss: 4.3296 0.0674 sec/batch
# Epoch 2/12 Iteration: 7700 Avg. Training loss: 4.3808 0.0683 sec/batch
# Epoch 2/12 Iteration: 7800 Avg. Training loss: 4.3474 0.0691 sec/batch
# Epoch 2/12 Iteration: 7900 Avg. Training loss: 4.3059 0.0682 sec/batch
# Epoch 2/12 Iteration: 8000 Avg. Training loss: 4.3261 0.0678 sec/batch
# Nearest to over:sector, mbit, welfare, battlegroup, lighters, avoidance, bullseye, bulk
# Nearest to only:direct, anything, unforgiving, cheesemaking, whenever, porosity, deprive, encounter
# Nearest to also:basie, panth, tracing, avogadro, pianos, hr, catch, unfounded
# Nearest to not:yet, cedi, any, tweaking, reserved, without, button, well
# Nearest to which:oboe, knowledge, photons, nominally, profiting, score, overview, stewardship
# Nearest to more:treatments, fractures, kourou, collides, rafters, fraenkel, extensive, speciesism
# Nearest to there:probabilistic, point, argued, less, adic, imperfections, longer, tighter
# Nearest to the:tribesman, a, nanometres, pau, definitively, disproportionately, sarcophagus, brunei
# Nearest to powers:balladeer, accord, democrats, protectorates, petition, commands, legislation, occupied
# Nearest to accepted:prussians, erv, monasticism, fantasyland, kitsch, clause, right, silenced
# Nearest to arts:junior, differentials, cardiff, klaus, keegan, disintegrating, pdl, portrait
# Nearest to instance:diffusing, facet, thus, denote, saved, uniting, caller, weekdays
# Nearest to cost:porritt, binitarianism, chip, lattices, fis, signals, reece, wage
# Nearest to ice:isospin, overworld, steady, water, piedmont, container, pratt, booking
# Nearest to pressure:gas, triads, heuristics, microfibrils, atmosphere, mms, findslot, kinetic
# Nearest to assembly:referendum, waltzing, passed, wikipedian, supersessionism, mainstay, pavlovich, voted
# Epoch 2/12 Iteration: 8100 Avg. Training loss: 4.3334 0.0689 sec/batch
# Epoch 2/12 Iteration: 8200 Avg. Training loss: 4.3020 0.0677 sec/batch
# Epoch 2/12 Iteration: 8300 Avg. Training loss: 4.3506 0.0676 sec/batch
# Epoch 2/12 Iteration: 8400 Avg. Training loss: 4.3603 0.0673 sec/batch
# Epoch 2/12 Iteration: 8500 Avg. Training loss: 4.3581 0.0689 sec/batch
# Epoch 2/12 Iteration: 8600 Avg. Training loss: 4.2833 0.0683 sec/batch
# Epoch 2/12 Iteration: 8700 Avg. Training loss: 4.2977 0.0671 sec/batch
# Epoch 2/12 Iteration: 8800 Avg. Training loss: 4.3050 0.0687 sec/batch
# Epoch 2/12 Iteration: 8900 Avg. Training loss: 4.2201 0.0677 sec/batch
# Epoch 2/12 Iteration: 9000 Avg. Training loss: 4.2852 0.0688 sec/batch
# Nearest to over:sector, lighters, battlegroup, mbit, biosphere, avoidance, welfare, guiana
# Nearest to only:cheesemaking, direct, porosity, unforgiving, anything, deprive, signifying, hermitian
# Nearest to also:basie, panth, tracing, avogadro, hr, pianos, other, intolerable
# Nearest to not:cedi, any, yet, reserved, tweaking, button, ribald, affirming
# Nearest to which:oboe, knowledge, nominally, photons, civilian, profiting, overview, grandees
# Nearest to more:treatments, fraenkel, fractures, rafters, kourou, speciesism, extensive, apart
# Nearest to there:probabilistic, argued, adic, erratically, alves, harmonizing, imperfections, syrians
# Nearest to the:a, tribesman, nanometres, is, adjusting, kcl, pau, definitively
# Nearest to powers:balladeer, protectorates, accord, commands, democrats, deputies, petition, complacency
# Nearest to accepted:prussians, erv, fantasyland, monasticism, kitsch, acknowledgement, silenced, chemists
# Nearest to arts:junior, differentials, klingons, cardiff, portrait, academy, schoolhouse, uzi
# Nearest to instance:diffusing, thus, facet, denote, caller, weekdays, saved, eschewed
# Nearest to cost:binitarianism, porritt, lattices, shops, wage, fis, signals, chip
# Nearest to ice:water, overworld, steady, isospin, container, piedmont, chorionic, calculated
# Nearest to pressure:gas, triads, heuristics, atmosphere, microfibrils, mms, findslot, gallons
# Nearest to assembly:referendum, voted, representatives, waltzing, passed, ephemera, parliament, senate
# Epoch 2/12 Iteration: 9100 Avg. Training loss: 4.3092 0.0701 sec/batch
# Epoch 2/12 Iteration: 9200 Avg. Training loss: 4.2604 0.0682 sec/batch
# Epoch 3/12 Iteration: 9300 Avg. Training loss: 4.3212 0.0328 sec/batch
# Epoch 3/12 Iteration: 9400 Avg. Training loss: 4.2554 0.0694 sec/batch
# Epoch 3/12 Iteration: 9500 Avg. Training loss: 4.2123 0.0691 sec/batch
# Epoch 3/12 Iteration: 9600 Avg. Training loss: 4.2164 0.0695 sec/batch
# Epoch 3/12 Iteration: 9700 Avg. Training loss: 4.2145 0.0684 sec/batch
# Epoch 3/12 Iteration: 9800 Avg. Training loss: 4.1867 0.0691 sec/batch
# Epoch 3/12 Iteration: 9900 Avg. Training loss: 4.2074 0.0697 sec/batch
# Epoch 3/12 Iteration: 10000 Avg. Training loss: 4.1419 0.0684 sec/batch
# Nearest to over:sector, battlegroup, mbit, lighters, bulk, into, airshow, biosphere
# Nearest to only:cheesemaking, direct, unforgiving, porosity, prompt, anything, signifying, whenever
# Nearest to also:basie, avogadro, panth, tracing, hr, pianos, bargained, existing
# Nearest to not:cedi, yet, any, affirming, reserved, button, tweaking, ribald
# Nearest to which:oboe, knowledge, nominally, ofc, grandees, civilian, profiting, nutcracker
# Nearest to more:treatments, fractures, kourou, apart, rafters, speciesism, fraenkel, yemeni
# Nearest to there:probabilistic, households, argued, imperfections, adic, harmonizing, abolition, sleek
# Nearest to the:a, sarcophagus, kcl, brunei, gust, is, pau, definitively
# Nearest to powers:protectorates, balladeer, accord, petition, deputies, complacency, commands, democrats
# Nearest to accepted:prussians, erv, fantasyland, kitsch, monasticism, acknowledgement, silenced, chemists
# Nearest to arts:junior, differentials, klingons, academy, cardiff, portrait, spirituals, pdl
# Nearest to instance:diffusing, caller, denote, thus, saved, facet, weekdays, uniting
# Nearest to cost:binitarianism, fis, newer, porritt, wage, shops, lattices, chip
# Nearest to ice:water, overworld, isospin, piedmont, booking, steady, container, chorionic
# Nearest to pressure:gas, heuristics, triads, atmosphere, findslot, mms, kinetic, microfibrils
# Nearest to assembly:referendum, waltzing, voted, representatives, ephemera, passed, wikipedian, constituencies
# Epoch 3/12 Iteration: 10100 Avg. Training loss: 4.2140 0.0697 sec/batch
# Epoch 3/12 Iteration: 10200 Avg. Training loss: 4.2045 0.0684 sec/batch
# Epoch 3/12 Iteration: 10300 Avg. Training loss: 4.1959 0.0690 sec/batch
# Epoch 3/12 Iteration: 10400 Avg. Training loss: 4.0902 0.0681 sec/batch
# Epoch 3/12 Iteration: 10500 Avg. Training loss: 4.1683 0.0686 sec/batch
# Epoch 3/12 Iteration: 10600 Avg. Training loss: 4.1472 0.0691 sec/batch
# Epoch 3/12 Iteration: 10700 Avg. Training loss: 4.1201 0.0688 sec/batch
# Epoch 3/12 Iteration: 10800 Avg. Training loss: 4.1392 0.0690 sec/batch
# Epoch 3/12 Iteration: 10900 Avg. Training loss: 4.1553 0.0681 sec/batch
# Epoch 3/12 Iteration: 11000 Avg. Training loss: 4.1561 0.0677 sec/batch
# Nearest to over:sector, mbit, lighters, battlegroup, bullseye, airshow, guiana, sardaukar
# Nearest to only:direct, cheesemaking, unforgiving, prompt, whenever, porosity, distinguish, signifying
# Nearest to also:basie, hr, avogadro, panth, tracing, bargained, other, broadened
# Nearest to not:any, yet, affirming, cedi, tweaking, button, reserved, promises
# Nearest to which:photons, oboe, knowledge, autocorrelation, nominally, profiting, penalties, connectedness
# Nearest to more:fractures, kourou, apart, treatments, inadvertent, clamp, rafters, fraenkel
# Nearest to there:probabilistic, adic, households, vee, harmonizing, argued, imperfections, alves
# Nearest to the:a, nanometres, sarcophagus, tribesman, kcl, adjusting, is, quelled
# Nearest to powers:protectorates, balladeer, accord, complacency, petition, deputies, democrats, withhold
# Nearest to accepted:prussians, erv, monasticism, fantasyland, chemists, kitsch, silenced, penitential
# Nearest to arts:junior, differentials, klingons, academy, portrait, spirituals, dancing, cardiff
# Nearest to instance:diffusing, saved, denote, caller, thus, weekdays, facet, eschewed
# Nearest to cost:binitarianism, newer, chip, porritt, fis, shops, signals, wage
# Nearest to ice:water, overworld, steady, piedmont, isospin, container, melting, supervillain
# Nearest to pressure:gas, atmosphere, triads, microfibrils, findslot, vapor, heuristics, kinetic
# Nearest to assembly:referendum, waltzing, representatives, constituencies, passed, bicameral, ephemera, wikipedian
# Epoch 3/12 Iteration: 11100 Avg. Training loss: 4.1331 0.0710 sec/batch
# Epoch 3/12 Iteration: 11200 Avg. Training loss: 4.2204 0.0692 sec/batch
# Epoch 3/12 Iteration: 11300 Avg. Training loss: 4.1884 0.0684 sec/batch
# Epoch 3/12 Iteration: 11400 Avg. Training loss: 4.1464 0.0687 sec/batch
# Epoch 3/12 Iteration: 11500 Avg. Training loss: 4.1230 0.0688 sec/batch
# Epoch 3/12 Iteration: 11600 Avg. Training loss: 4.1854 0.0693 sec/batch
# Epoch 3/12 Iteration: 11700 Avg. Training loss: 4.1735 0.0695 sec/batch
# Epoch 3/12 Iteration: 11800 Avg. Training loss: 4.1189 0.0688 sec/batch
# Epoch 3/12 Iteration: 11900 Avg. Training loss: 4.1263 0.0678 sec/batch
# Epoch 3/12 Iteration: 12000 Avg. Training loss: 4.1386 0.0689 sec/batch
# Nearest to over:sector, mbit, lighters, battlegroup, bullseye, airshow, biosphere, sardaukar
# Nearest to only:direct, cheesemaking, distinguish, unforgiving, porosity, signifying, prompt, variants
# Nearest to also:basie, hr, avogadro, panth, bargained, tracing, taki, nep
# Nearest to not:affirming, any, cedi, yet, tweaking, reserved, button, daybreak
# Nearest to which:photons, oboe, autocorrelation, knowledge, connectedness, profiting, nominally, vocative
# Nearest to more:kourou, apart, collides, clamp, treatments, fractures, extensive, fraenkel
# Nearest to there:probabilistic, adic, harmonizing, households, argued, vee, alves, decatur
# Nearest to the:a, tribesman, sarcophagus, is, nanometres, quelled, disproportionately, dickensian
# Nearest to powers:protectorates, balladeer, deputies, withhold, accord, petition, democrats, commands
# Nearest to accepted:erv, prussians, chemists, monasticism, fantasyland, silenced, kitsch, penitential
# Nearest to arts:junior, differentials, academy, klingons, dancing, portrait, cardiff, spirituals
# Nearest to instance:diffusing, saved, denote, facet, weekdays, caller, thus, aneristic
# Nearest to cost:binitarianism, porritt, wage, fis, newer, shops, herons, chip
# Nearest to ice:water, overworld, piedmont, frost, isospin, melting, pratt, seawater
# Nearest to pressure:gas, atmosphere, triads, ignited, kinetic, microfibrils, findslot, vapor
# Nearest to assembly:referendum, constituencies, representatives, parliament, bicameral, waltzing, passed, ephemera
# Epoch 3/12 Iteration: 12100 Avg. Training loss: 4.1656 0.0697 sec/batch
# Epoch 3/12 Iteration: 12200 Avg. Training loss: 4.1444 0.0693 sec/batch
# Epoch 3/12 Iteration: 12300 Avg. Training loss: 4.1719 0.0686 sec/batch
# Epoch 3/12 Iteration: 12400 Avg. Training loss: 4.1760 0.0685 sec/batch
# Epoch 3/12 Iteration: 12500 Avg. Training loss: 4.1419 0.0697 sec/batch
# Epoch 3/12 Iteration: 12600 Avg. Training loss: 4.0858 0.0677 sec/batch
# Epoch 3/12 Iteration: 12700 Avg. Training loss: 4.1585 0.0687 sec/batch
# Epoch 3/12 Iteration: 12800 Avg. Training loss: 4.1016 0.0695 sec/batch
# Epoch 3/12 Iteration: 12900 Avg. Training loss: 4.1827 0.0681 sec/batch
# Epoch 3/12 Iteration: 13000 Avg. Training loss: 4.2003 0.0688 sec/batch
# Nearest to over:sector, mbit, lighters, battlegroup, airshow, biosphere, bulk, bullseye
# Nearest to only:direct, cheesemaking, unforgiving, incidences, hermitian, largo, distinguish, signifying
# Nearest to also:basie, hr, panth, taki, avogadro, bargained, tracing, nep
# Nearest to not:any, cedi, affirming, reserved, yet, tweaking, exempting, button
# Nearest to which:oboe, nominally, profiting, photons, autocorrelation, dowry, bermontians, ndnis
# Nearest to more:kourou, apart, yemeni, radclyffe, rafters, collides, speciesism, treatments
# Nearest to there:households, adic, harmonizing, alves, probabilistic, decatur, abolition, onomatopoeic
# Nearest to the:a, sarcophagus, tribesman, quelled, is, pius, emirs, drayton
# Nearest to powers:protectorates, balladeer, withhold, deputies, complacency, petition, theoretically, accord
# Nearest to accepted:prussians, erv, monasticism, chemists, fantasyland, kitsch, silenced, penitential
# Nearest to arts:junior, academy, klingons, differentials, portrait, dancing, colleges, schoolhouse
# Nearest to instance:diffusing, saved, denote, caller, facet, thus, weekdays, aneristic
# Nearest to cost:binitarianism, fis, wage, porritt, shops, newer, herons, chip
# Nearest to ice:overworld, water, frost, melting, piedmont, supervillain, calculated, booking
# Nearest to pressure:gas, atmosphere, ignited, triads, kinetic, microfibrils, findslot, heuristics
# Nearest to assembly:referendum, constituencies, bicameral, representatives, passed, waltzing, parliament, ephemera
# Epoch 3/12 Iteration: 13100 Avg. Training loss: 4.2060 0.0693 sec/batch
# Epoch 3/12 Iteration: 13200 Avg. Training loss: 4.0977 0.0675 sec/batch
# Epoch 3/12 Iteration: 13300 Avg. Training loss: 4.1387 0.0685 sec/batch
# Epoch 3/12 Iteration: 13400 Avg. Training loss: 4.0988 0.0681 sec/batch
# Epoch 3/12 Iteration: 13500 Avg. Training loss: 3.9981 0.0680 sec/batch
# Epoch 3/12 Iteration: 13600 Avg. Training loss: 4.1178 0.0682 sec/batch
# Epoch 3/12 Iteration: 13700 Avg. Training loss: 4.1080 0.0680 sec/batch
# Epoch 3/12 Iteration: 13800 Avg. Training loss: 4.1050 0.0695 sec/batch
# Epoch 4/12 Iteration: 13900 Avg. Training loss: 4.1520 0.0156 sec/batch
# Epoch 4/12 Iteration: 14000 Avg. Training loss: 4.0968 0.0664 sec/batch
# Nearest to over:sector, mbit, lighters, bulk, battlegroup, biosphere, bullseye, airshow
# Nearest to only:direct, cheesemaking, distinguish, prompt, hermitian, unforgiving, variants, embankments
# Nearest to also:basie, hr, avogadro, other, taki, bargained, broadened, tracing
# Nearest to not:any, cedi, button, affirming, yet, reserved, tweaking, exempting
# Nearest to which:autocorrelation, oboe, photons, nominally, a, profiting, jackal, vocative
# Nearest to more:kourou, collides, apart, rafters, yemeni, treatments, less, standard
# Nearest to there:households, probabilistic, adic, harmonizing, alves, imperfections, sleek, decatur
# Nearest to the:a, is, sarcophagus, nanometres, megalopolis, dickensian, clever, an
# Nearest to powers:protectorates, balladeer, withhold, complacency, deputies, petition, require, accord
# Nearest to accepted:prussians, erv, fantasyland, monasticism, chemists, kitsch, silenced, starling
# Nearest to arts:junior, academy, differentials, klingons, colleges, dancing, students, portrait
# Nearest to instance:diffusing, denote, caller, saved, facet, aneristic, weekdays, deh
# Nearest to cost:binitarianism, fis, wage, newer, porritt, chip, costs, herons
# Nearest to ice:water, frost, overworld, debris, melting, piedmont, macaroni, container
# Nearest to pressure:gas, ignited, aborted, atmosphere, microfibrils, triads, kinetic, heuristics
# Nearest to assembly:referendum, representatives, constituencies, passed, waltzing, ephemera, lcms, wikipedian
# Epoch 4/12 Iteration: 14100 Avg. Training loss: 4.0207 0.0685 sec/batch
# Epoch 4/12 Iteration: 14200 Avg. Training loss: 4.0450 0.0679 sec/batch
# Epoch 4/12 Iteration: 14300 Avg. Training loss: 4.0721 0.0693 sec/batch
# Epoch 4/12 Iteration: 14400 Avg. Training loss: 4.0278 0.0685 sec/batch
# Epoch 4/12 Iteration: 14500 Avg. Training loss: 4.0697 0.0679 sec/batch
# Epoch 4/12 Iteration: 14600 Avg. Training loss: 4.0084 0.0683 sec/batch
# Epoch 4/12 Iteration: 14700 Avg. Training loss: 4.0564 0.0682 sec/batch
# Epoch 4/12 Iteration: 14800 Avg. Training loss: 4.0542 0.0691 sec/batch
# Epoch 4/12 Iteration: 14900 Avg. Training loss: 4.1025 0.0688 sec/batch
# Epoch 4/12 Iteration: 15000 Avg. Training loss: 3.9649 0.0686 sec/batch
# Nearest to over:sector, mbit, battlegroup, lighters, bulk, airshow, bullseye, biosphere
# Nearest to only:direct, cheesemaking, distinguish, unforgiving, incidences, prompt, signifying, caml
# Nearest to also:basie, hr, other, avogadro, taki, broadened, bargained, existing
# Nearest to not:any, cedi, button, affirming, yet, tweaking, reserved, importation
# Nearest to which:oboe, autocorrelation, a, nominally, photons, dowry, imprisoning, trainee
# Nearest to more:apart, less, clamp, tonne, kourou, rafters, inadvertent, treatments
# Nearest to there:households, adic, probabilistic, decatur, householder, vee, families, sleek
# Nearest to the:a, is, sarcophagus, quelled, an, spires, megalopolis, charter
# Nearest to powers:protectorates, balladeer, withhold, deputies, complacency, require, petition, accord
# Nearest to accepted:fantasyland, erv, prussians, chemists, monasticism, kitsch, tobacco, silenced
# Nearest to arts:junior, academy, differentials, klingons, colleges, dancing, students, portrait
# Nearest to instance:diffusing, caller, aneristic, saved, thus, denote, facet, weekdays
# Nearest to cost:binitarianism, fis, wage, herons, newer, porritt, chip, ride
# Nearest to ice:frost, water, overworld, piedmont, debris, melting, burnaby, macaroni
# Nearest to pressure:gas, ignited, atmosphere, microfibrils, aborted, kinetic, findslot, triads
# Nearest to assembly:referendum, representatives, constituencies, parliament, bicameral, passed, parliamentary, senate
# Epoch 4/12 Iteration: 15100 Avg. Training loss: 4.0182 0.0710 sec/batch
# Epoch 4/12 Iteration: 15200 Avg. Training loss: 3.9966 0.0682 sec/batch
# Epoch 4/12 Iteration: 15300 Avg. Training loss: 3.9872 0.0682 sec/batch
# Epoch 4/12 Iteration: 15400 Avg. Training loss: 4.0348 0.0681 sec/batch
# Epoch 4/12 Iteration: 15500 Avg. Training loss: 4.0427 0.0686 sec/batch
# Epoch 4/12 Iteration: 15600 Avg. Training loss: 4.0251 0.0681 sec/batch
# Epoch 4/12 Iteration: 15700 Avg. Training loss: 4.0391 0.0688 sec/batch
# Epoch 4/12 Iteration: 15800 Avg. Training loss: 4.0808 0.0678 sec/batch
# Epoch 4/12 Iteration: 15900 Avg. Training loss: 4.0469 0.0684 sec/batch
# Epoch 4/12 Iteration: 16000 Avg. Training loss: 4.0081 0.0681 sec/batch
# Nearest to over:mbit, sector, lighters, battlegroup, airshow, bulk, biosphere, bullseye
# Nearest to only:direct, distinguish, unforgiving, cheesemaking, prompt, signifying, variants, porosity
# Nearest to also:basie, hr, other, avogadro, taki, bargained, broadened, nep
# Nearest to not:any, affirming, cedi, button, dbmss, tweaking, exempting, yet
# Nearest to which:oboe, autocorrelation, photons, a, imprisoning, connectedness, unachievable, nominally
# Nearest to more:apart, less, clamp, kourou, whither, fraenkel, standard, inadvertent
# Nearest to there:households, probabilistic, adic, decatur, are, vee, families, every
# Nearest to the:a, is, an, nanometres, sarcophagus, superficial, megalopolis, errol
# Nearest to powers:protectorates, withhold, complacency, balladeer, deputies, require, theoretically, finiteness
# Nearest to accepted:erv, fantasyland, prussians, chemists, monasticism, kitsch, starling, judicious
# Nearest to arts:academy, junior, differentials, klingons, colleges, dancing, students, portrait
# Nearest to instance:diffusing, caller, facet, thus, aneristic, saved, is, weekdays
# Nearest to cost:binitarianism, fis, wage, chip, shops, herons, porritt, ride
# Nearest to ice:frost, overworld, piedmont, calculated, water, debris, melting, burnaby
# Nearest to pressure:atmosphere, gas, ignited, vapor, microfibrils, kinetic, findslot, dosing
# Nearest to assembly:representatives, referendum, constituencies, bicameral, passed, parliament, senate, legislative
# Epoch 4/12 Iteration: 16100 Avg. Training loss: 4.0087 0.0698 sec/batch
# Epoch 4/12 Iteration: 16200 Avg. Training loss: 4.0385 0.0686 sec/batch
# Epoch 4/12 Iteration: 16300 Avg. Training loss: 4.0745 0.0696 sec/batch
# Epoch 4/12 Iteration: 16400 Avg. Training loss: 4.0044 0.0684 sec/batch
# Epoch 4/12 Iteration: 16500 Avg. Training loss: 4.0266 0.0681 sec/batch
# Epoch 4/12 Iteration: 16600 Avg. Training loss: 4.0116 0.0687 sec/batch
# Epoch 4/12 Iteration: 16700 Avg. Training loss: 4.0399 0.0685 sec/batch
# Epoch 4/12 Iteration: 16800 Avg. Training loss: 4.0165 0.0694 sec/batch
# Epoch 4/12 Iteration: 16900 Avg. Training loss: 4.0444 0.0684 sec/batch
# Epoch 4/12 Iteration: 17000 Avg. Training loss: 4.0470 0.0690 sec/batch
# Nearest to over:mbit, sector, battlegroup, lighters, airshow, bulk, bullseye, sardaukar
# Nearest to only:direct, distinguish, cheesemaking, prompt, hermitian, variants, unforgiving, incidences
# Nearest to also:basie, hr, other, taki, broadened, bargained, avogadro, existing
# Nearest to not:any, cedi, affirming, button, exempting, tweaking, importation, reserved
# Nearest to which:oboe, a, autocorrelation, nominally, photons, connectedness, profiting, jackal
# Nearest to more:apart, less, standard, kourou, whither, rafters, collides, clamp
# Nearest to there:households, probabilistic, decatur, adic, families, every, harmonizing, sleek
# Nearest to the:a, is, of, sarcophagus, an, superficial, spires, slovenes
# Nearest to powers:protectorates, withhold, deputies, exercised, balladeer, kamakura, complacency, prerogatives
# Nearest to accepted:erv, prussians, fantasyland, monasticism, chemists, silenced, tobacco, starling
# Nearest to arts:academy, junior, klingons, differentials, dancing, interdisciplinary, colleges, schoolhouse
# Nearest to instance:diffusing, facet, weekdays, caller, aneristic, saved, thus, is
# Nearest to cost:binitarianism, wage, fis, ride, grossed, herons, shops, chip
# Nearest to ice:overworld, calculated, piedmont, frost, water, melting, burnaby, hoppers
# Nearest to pressure:gas, atmosphere, ignited, kinetic, microfibrils, vapor, aborted, findslot
# Nearest to assembly:representatives, referendum, parliamentary, bicameral, constituencies, senate, parliament, passed
# Epoch 4/12 Iteration: 17100 Avg. Training loss: 4.0012 0.0695 sec/batch
# Epoch 4/12 Iteration: 17200 Avg. Training loss: 4.0112 0.0691 sec/batch
# Epoch 4/12 Iteration: 17300 Avg. Training loss: 3.9840 0.0696 sec/batch
# Epoch 4/12 Iteration: 17400 Avg. Training loss: 4.0477 0.0696 sec/batch
# Epoch 4/12 Iteration: 17500 Avg. Training loss: 4.0795 0.0683 sec/batch
# Epoch 4/12 Iteration: 17600 Avg. Training loss: 4.1092 0.0690 sec/batch
# Epoch 4/12 Iteration: 17700 Avg. Training loss: 4.1000 0.0684 sec/batch
# Epoch 4/12 Iteration: 17800 Avg. Training loss: 4.0371 0.0681 sec/batch
# Epoch 4/12 Iteration: 17900 Avg. Training loss: 3.9767 0.0685 sec/batch
# Epoch 4/12 Iteration: 18000 Avg. Training loss: 3.9905 0.0675 sec/batch
# Nearest to over:mbit, sector, battlegroup, lighters, airshow, bulk, bullseye, coastal
# Nearest to only:direct, cheesemaking, prompt, unforgiving, distinguish, substitutions, incidences, atreus
# Nearest to also:basie, hr, other, the, taki, avogadro, broadened, existing
# Nearest to not:any, cedi, button, affirming, exempting, tweaking, reserved, dbmss
# Nearest to which:a, oboe, nominally, autocorrelation, civilian, clog, oblique, the
# Nearest to more:apart, less, kourou, standard, whither, yemeni, rafters, collides
# Nearest to there:households, decatur, adic, families, probabilistic, are, every, householder
# Nearest to the:a, is, of, for, an, superficial, megalopolis, spires
# Nearest to powers:protectorates, withhold, balladeer, complacency, deputies, kamakura, drury, require
# Nearest to accepted:erv, fantasyland, prussians, chemists, monasticism, mostar, silenced, judicious
# Nearest to arts:academy, junior, differentials, klingons, interdisciplinary, colleges, dancing, students
# Nearest to instance:is, diffusing, caller, thus, facet, aneristic, denote, weekdays
# Nearest to cost:binitarianism, wage, herons, fis, ride, grossed, shops, adopting
# Nearest to ice:overworld, frost, hoppers, calculated, fishers, melting, burnaby, debris
# Nearest to pressure:gas, atmosphere, kinetic, ignited, microfibrils, aborted, vapor, anson
# Nearest to assembly:referendum, representatives, bicameral, senate, parliamentary, passed, legislative, lcms
# Epoch 4/12 Iteration: 18100 Avg. Training loss: 3.9523 0.0707 sec/batch
# Epoch 4/12 Iteration: 18200 Avg. Training loss: 3.9903 0.0695 sec/batch
# Epoch 4/12 Iteration: 18300 Avg. Training loss: 4.0085 0.0692 sec/batch
# Epoch 4/12 Iteration: 18400 Avg. Training loss: 3.9971 0.0686 sec/batch
# Epoch 4/12 Iteration: 18500 Avg. Training loss: 4.0396 0.0689 sec/batch
# Epoch 5/12 Iteration: 18600 Avg. Training loss: 3.9917 0.0663 sec/batch
# Epoch 5/12 Iteration: 18700 Avg. Training loss: 3.9717 0.0685 sec/batch
# Epoch 5/12 Iteration: 18800 Avg. Training loss: 3.9751 0.0678 sec/batch
# Epoch 5/12 Iteration: 18900 Avg. Training loss: 3.9698 0.0690 sec/batch
# Epoch 5/12 Iteration: 19000 Avg. Training loss: 3.9401 0.0690 sec/batch
# Nearest to over:mbit, sector, battlegroup, bulk, lighters, airshow, bullseye, years
# Nearest to only:direct, cheesemaking, atreus, distinguish, prompt, unforgiving, substitutions, paradoxically
# Nearest to also:basie, other, hr, avogadro, taki, the, agere, bargained
# Nearest to not:any, cedi, affirming, exempting, button, dbmss, importation, tweaking
# Nearest to which:a, oboe, the, clog, nominally, dowry, autocorrelation, jackal
# Nearest to more:less, apart, kourou, standard, yemeni, rafters, tonne, whither
# Nearest to there:households, decatur, families, adic, probabilistic, are, householder, every
# Nearest to the:a, is, of, an, sarcophagus, for, spires, megalopolis
# Nearest to powers:protectorates, withhold, complacency, balladeer, deputies, drury, kamakura, exercised
# Nearest to accepted:fantasyland, erv, chemists, monasticism, prussians, mostar, silenced, tobacco
# Nearest to arts:academy, junior, differentials, klingons, colleges, interdisciplinary, dancing, qigong
# Nearest to instance:diffusing, caller, is, abbreviate, aneristic, facet, weekdays, thus
# Nearest to cost:binitarianism, wage, fis, grossed, herons, shops, ride, dismantle
# Nearest to ice:overworld, frost, fishers, hoppers, debris, piedmont, melting, burnaby
# Nearest to pressure:gas, kinetic, atmosphere, aborted, spl, ignited, dosing, microfibrils
# Nearest to assembly:referendum, senate, representatives, passed, lcms, wikipedian, parliamentary, ephemera
# Epoch 5/12 Iteration: 19100 Avg. Training loss: 3.9359 0.0702 sec/batch
# Epoch 5/12 Iteration: 19200 Avg. Training loss: 3.9116 0.0686 sec/batch
# Epoch 5/12 Iteration: 19300 Avg. Training loss: 3.9640 0.0677 sec/batch
# Epoch 5/12 Iteration: 19400 Avg. Training loss: 3.9614 0.0678 sec/batch
# Epoch 5/12 Iteration: 19500 Avg. Training loss: 3.9834 0.0680 sec/batch
# Epoch 5/12 Iteration: 19600 Avg. Training loss: 3.9615 0.0682 sec/batch
# Epoch 5/12 Iteration: 19700 Avg. Training loss: 3.8495 0.0673 sec/batch
# Epoch 5/12 Iteration: 19800 Avg. Training loss: 3.9499 0.0683 sec/batch
# Epoch 5/12 Iteration: 19900 Avg. Training loss: 3.8779 0.0687 sec/batch
# Epoch 5/12 Iteration: 20000 Avg. Training loss: 3.9398 0.0684 sec/batch
# Nearest to over:mbit, sector, battlegroup, lighters, years, bulk, bullseye, airshow
# Nearest to only:direct, distinguish, cheesemaking, unforgiving, prompt, substitutions, atreus, for
# Nearest to also:basie, other, hr, the, taki, is, broadened, avogadro
# Nearest to not:any, affirming, cedi, exempting, button, importation, yet, dbmss
# Nearest to which:a, the, nominally, dowry, oboe, clog, berbers, connectedness
# Nearest to more:apart, less, kourou, standard, clamp, inadvertent, tonne, there
# Nearest to there:households, adic, families, decatur, probabilistic, every, are, is
# Nearest to the:a, is, of, for, an, and, which, in
# Nearest to powers:protectorates, withhold, deputies, complacency, balladeer, kamakura, exercised, prerogatives
# Nearest to accepted:erv, fantasyland, chemists, monasticism, prussians, silenced, judicious, mostar
# Nearest to arts:academy, junior, differentials, klingons, interdisciplinary, qigong, colleges, art
# Nearest to instance:diffusing, caller, is, aneristic, family, weekdays, saved, dwarfed
# Nearest to cost:binitarianism, wage, fis, herons, buckinghamshire, grossed, slowdown, ride
# Nearest to ice:hoppers, fishers, overworld, frost, calculated, melting, debris, burnaby
# Nearest to pressure:gas, ignited, atmosphere, dosing, kinetic, exchanger, vapor, microfibrils
# Nearest to assembly:referendum, senate, representatives, passed, parliamentary, legislative, bicameral, wikipedian
# Epoch 5/12 Iteration: 20100 Avg. Training loss: 3.9447 0.0778 sec/batch
# Epoch 5/12 Iteration: 20200 Avg. Training loss: 3.9465 0.0683 sec/batch
# Epoch 5/12 Iteration: 20300 Avg. Training loss: 3.9504 0.0681 sec/batch
# Epoch 5/12 Iteration: 20400 Avg. Training loss: 3.9456 0.0686 sec/batch
# Epoch 5/12 Iteration: 20500 Avg. Training loss: 3.9950 0.0683 sec/batch
# Epoch 5/12 Iteration: 20600 Avg. Training loss: 3.8985 0.0681 sec/batch
# Epoch 5/12 Iteration: 20700 Avg. Training loss: 3.9192 0.0679 sec/batch
# Epoch 5/12 Iteration: 20800 Avg. Training loss: 3.9444 0.0669 sec/batch
# Epoch 5/12 Iteration: 20900 Avg. Training loss: 3.9726 0.0679 sec/batch
# Epoch 5/12 Iteration: 21000 Avg. Training loss: 3.9584 0.0690 sec/batch
# Nearest to over:mbit, sector, battlegroup, lighters, bulk, airshow, years, bullseye
# Nearest to only:direct, prompt, distinguish, unforgiving, recursively, zwingli, example, substitutions
# Nearest to also:basie, other, the, hr, is, broadened, taki, avogadro
# Nearest to not:any, affirming, button, exempting, tweaking, cedi, daybreak, reserved
# Nearest to which:a, the, oboe, nominally, dowry, connectedness, photons, autocorrelation
# Nearest to more:less, apart, standard, fraenkel, kourou, alternatives, apparent, enzymatic
# Nearest to there:households, adic, families, decatur, probabilistic, every, is, are
# Nearest to the:a, of, is, for, an, and, also, on
# Nearest to powers:protectorates, withhold, deputies, exercised, balladeer, kamakura, pacifists, indirectly
# Nearest to accepted:erv, fantasyland, chemists, monasticism, judicious, tobacco, mostar, prussians
# Nearest to arts:academy, junior, interdisciplinary, klingons, differentials, qigong, colleges, dancing
# Nearest to instance:diffusing, caller, is, aneristic, abbreviate, weekdays, denote, family
# Nearest to cost:binitarianism, wage, herons, fis, ride, grossed, buckinghamshire, shops
# Nearest to ice:fishers, hoppers, overworld, hockey, calculated, frost, burnaby, melting
# Nearest to pressure:ignited, gas, kinetic, atmosphere, spl, vapor, exchanger, gallons
# Nearest to assembly:passed, representatives, senate, referendum, legislative, parliamentary, lcms, wikipedian
# Epoch 5/12 Iteration: 21100 Avg. Training loss: 3.9616 0.0698 sec/batch
# Epoch 5/12 Iteration: 21200 Avg. Training loss: 3.9400 0.0682 sec/batch
# Epoch 5/12 Iteration: 21300 Avg. Training loss: 3.9404 0.0680 sec/batch
# Epoch 5/12 Iteration: 21400 Avg. Training loss: 3.9862 0.0678 sec/batch
# Epoch 5/12 Iteration: 21500 Avg. Training loss: 3.9733 0.0680 sec/batch
# Epoch 5/12 Iteration: 21600 Avg. Training loss: 3.9753 0.0689 sec/batch
# Epoch 5/12 Iteration: 21700 Avg. Training loss: 3.9456 0.0680 sec/batch
# Epoch 5/12 Iteration: 21800 Avg. Training loss: 3.8943 0.0694 sec/batch
# Epoch 5/12 Iteration: 21900 Avg. Training loss: 3.9229 0.0680 sec/batch
# Epoch 5/12 Iteration: 22000 Avg. Training loss: 3.9814 0.0687 sec/batch
# Nearest to over:mbit, sector, bulk, battlegroup, lighters, years, airshow, four
# Nearest to only:direct, distinguish, prompt, zwingli, recursively, unforgiving, example, cheesemaking
# Nearest to also:the, basie, other, hr, is, avogadro, taki, broadened
# Nearest to not:any, affirming, cedi, exempting, button, tweaking, reserved, dbmss
# Nearest to which:a, the, nominally, on, dowry, photons, clog, that
# Nearest to more:less, apart, kourou, standard, inadvertent, tonne, timekeeping, seu
# Nearest to there:households, decatur, is, adic, are, families, probabilistic, living
# Nearest to the:a, of, is, for, on, an, and, also
# Nearest to powers:withhold, protectorates, deputies, exercised, indirectly, kamakura, drury, pacifists
# Nearest to accepted:erv, fantasyland, chemists, monasticism, prussians, mostar, silenced, tobacco
# Nearest to arts:academy, junior, interdisciplinary, differentials, klingons, qigong, colleges, portrait
# Nearest to instance:diffusing, is, caller, aneristic, dwarfed, facet, thus, family
# Nearest to cost:binitarianism, wage, fis, herons, buckinghamshire, ride, grossed, slowdown
# Nearest to ice:overworld, hockey, fishers, hoppers, calculated, debris, seawater, melting
# Nearest to pressure:ignited, atmosphere, gas, spl, anson, kinetic, aborted, findslot
# Nearest to assembly:representatives, senate, referendum, passed, legislative, parliamentary, bicameral, lcms
# Epoch 5/12 Iteration: 22100 Avg. Training loss: 3.9416 0.0694 sec/batch
# Epoch 5/12 Iteration: 22200 Avg. Training loss: 4.0694 0.0691 sec/batch
# Epoch 5/12 Iteration: 22300 Avg. Training loss: 3.9993 0.0684 sec/batch
# ...
# Epoch 11/12 Iteration: 47100 Avg. Training loss: 3.7846 0.0701 sec/batch
# Epoch 11/12 Iteration: 47200 Avg. Training loss: 3.7650 0.0669 sec/batch
# Epoch 11/12 Iteration: 47300 Avg. Training loss: 3.8213 0.0683 sec/batch
# Epoch 11/12 Iteration: 47400 Avg. Training loss: 3.6628 0.0687 sec/batch
# Epoch 11/12 Iteration: 47500 Avg. Training loss: 3.7306 0.0681 sec/batch
# Epoch 11/12 Iteration: 47600 Avg. Training loss: 3.7642 0.0682 sec/batch
# Epoch 11/12 Iteration: 47700 Avg. Training loss: 3.6669 0.0680 sec/batch
# Epoch 11/12 Iteration: 47800 Avg. Training loss: 3.7599 0.0679 sec/batch
# Epoch 11/12 Iteration: 47900 Avg. Training loss: 3.7773 0.0681 sec/batch
# Epoch 11/12 Iteration: 48000 Avg. Training loss: 3.7505 0.0687 sec/batch
# Nearest to over:years, mbit, four, zero, in, is, distributed, two
# Nearest to only:direct, however, for, and, is, that, but, to
# Nearest to also:and, is, the, of, are, for, in, other
# Nearest to not:any, be, that, still, it, a, is, many
# Nearest to which:the, a, from, of, is, on, in, an
# Nearest to more:less, most, are, apart, but, could, there, their
# Nearest to there:of, are, is, least, for, families, many, that
# Nearest to the:a, of, and, for, in, to, which, is
# Nearest to powers:superhuman, marvel, pacifists, withhold, indirectly, spider, protectorates, costumed
# Nearest to accepted:mostar, although, tobacco, silenced, chemists, revolver, locations, fantasyland
# Nearest to arts:qigong, academy, jujutsu, martial, crafts, jutsu, techniques, interdisciplinary
# Nearest to instance:for, memorized, shifted, aneristic, abbreviate, simplified, arbitrarily, dwarfed
# Nearest to cost:buckinghamshire, costs, ride, medusa, eitc, binitarianism, wage, devises
# Nearest to ice:frozen, debris, hockey, warming, glaciers, swedes, remaining, defendants
# Nearest to pressure:vapor, pressures, spl, exchanger, aborted, antonescu, silicon, anemometers
# Nearest to assembly:aznavour, lcms, legislative, burlington, ephemera, assembl, nanoscale, representatives
# Epoch 11/12 Iteration: 48100 Avg. Training loss: 3.7610 0.0700 sec/batch
# Epoch 11/12 Iteration: 48200 Avg. Training loss: 3.8197 0.0682 sec/batch
# Epoch 11/12 Iteration: 48300 Avg. Training loss: 3.7583 0.0685 sec/batch
# Epoch 11/12 Iteration: 48400 Avg. Training loss: 3.7190 0.0673 sec/batch
# Epoch 11/12 Iteration: 48500 Avg. Training loss: 3.7426 0.0691 sec/batch
# Epoch 11/12 Iteration: 48600 Avg. Training loss: 3.7863 0.0689 sec/batch
# Epoch 11/12 Iteration: 48700 Avg. Training loss: 3.7872 0.0689 sec/batch
# Epoch 11/12 Iteration: 48800 Avg. Training loss: 3.7429 0.0691 sec/batch
# Epoch 11/12 Iteration: 48900 Avg. Training loss: 3.7199 0.0682 sec/batch
# Epoch 11/12 Iteration: 49000 Avg. Training loss: 3.7869 0.0690 sec/batch
# Nearest to over:years, mbit, zero, four, in, by, two, is
# Nearest to only:direct, however, and, for, following, but, is, s
# Nearest to also:is, of, and, the, are, see, other, for
# Nearest to not:any, be, still, it, that, the, a, affirming
# Nearest to which:the, a, from, of, is, on, in, an
# Nearest to more:are, less, most, apart, but, than, there, with
# Nearest to there:of, are, is, least, living, for, families, many
# Nearest to the:of, a, for, and, in, to, which, is
# Nearest to powers:marvel, superhuman, withhold, indirectly, pacifists, spider, protectorates, chosen
# Nearest to accepted:mostar, tobacco, concerned, revolver, although, fantasyland, rather, chemists
# Nearest to arts:qigong, academy, martial, jujutsu, crafts, discipline, interdisciplinary, jutsu
# Nearest to instance:for, memorized, aneristic, dwarfed, paraphrased, burdens, ruins, abbreviate
# Nearest to cost:buckinghamshire, costs, ride, wage, eitc, binitarianism, medusa, devises
# Nearest to ice:glaciers, warming, debris, frozen, hockey, swedes, remaining, eocene
# Nearest to pressure:pressures, spl, vapor, aborted, exchanger, antonescu, president, anson
# Nearest to assembly:aznavour, legislative, lcms, parliamentary, assembl, ephemera, burlington, representatives
# Epoch 11/12 Iteration: 49100 Avg. Training loss: 3.7728 0.0692 sec/batch
# Epoch 11/12 Iteration: 49200 Avg. Training loss: 3.8085 0.0690 sec/batch
# Epoch 11/12 Iteration: 49300 Avg. Training loss: 3.7606 0.0689 sec/batch
# Epoch 11/12 Iteration: 49400 Avg. Training loss: 3.7995 0.0680 sec/batch
# Epoch 11/12 Iteration: 49500 Avg. Training loss: 3.7078 0.0687 sec/batch
# Epoch 11/12 Iteration: 49600 Avg. Training loss: 3.7577 0.0673 sec/batch
# Epoch 11/12 Iteration: 49700 Avg. Training loss: 3.7589 0.0680 sec/batch
# Epoch 11/12 Iteration: 49800 Avg. Training loss: 3.7621 0.0679 sec/batch
# Epoch 11/12 Iteration: 49900 Avg. Training loss: 3.8351 0.0675 sec/batch
# Epoch 11/12 Iteration: 50000 Avg. Training loss: 3.8627 0.0687 sec/batch
# Nearest to over:years, in, is, four, mbit, zero, by, to
# Nearest to only:however, for, following, direct, and, s, but, to
# Nearest to also:is, the, of, and, in, which, other, for
# Nearest to not:any, be, still, the, it, a, to, that
# Nearest to which:the, a, from, as, an, of, in, with
# Nearest to more:less, apart, are, most, but, than, there, standard
# Nearest to there:are, of, is, living, least, for, families, many
# Nearest to the:a, of, for, and, in, to, which, by
# Nearest to powers:superhuman, marvel, withhold, pacifists, indirectly, spider, protectorates, prerogatives
# Nearest to accepted:mostar, although, silenced, concerned, revolver, tobacco, fantasyland, locations
# Nearest to arts:qigong, academy, martial, jujutsu, crafts, interdisciplinary, discipline, jutsu
# Nearest to instance:for, memorized, aneristic, dwarfed, burdens, ruins, paraphrased, shifted
# Nearest to cost:buckinghamshire, costs, ride, binitarianism, wage, medusa, devises, eitc
# Nearest to ice:hockey, debris, glaciers, swedes, frozen, warming, khanty, barrington
# Nearest to pressure:pressures, spl, vapor, exchanger, aborted, antonescu, president, anson
# Nearest to assembly:aznavour, legislative, lcms, assembl, parliamentary, referendum, ephemera, burlington
# Epoch 11/12 Iteration: 50100 Avg. Training loss: 3.7766 0.0697 sec/batch
# Epoch 11/12 Iteration: 50200 Avg. Training loss: 3.7857 0.0691 sec/batch
# Epoch 11/12 Iteration: 50300 Avg. Training loss: 3.6923 0.0673 sec/batch
# Epoch 11/12 Iteration: 50400 Avg. Training loss: 3.7190 0.0684 sec/batch
# Epoch 11/12 Iteration: 50500 Avg. Training loss: 3.6630 0.0686 sec/batch
# Epoch 11/12 Iteration: 50600 Avg. Training loss: 3.8051 0.0682 sec/batch
# Epoch 11/12 Iteration: 50700 Avg. Training loss: 3.7771 0.0687 sec/batch
# Epoch 11/12 Iteration: 50800 Avg. Training loss: 3.7477 0.0682 sec/batch
# Epoch 12/12 Iteration: 50900 Avg. Training loss: 3.7925 0.0099 sec/batch
# Epoch 12/12 Iteration: 51000 Avg. Training loss: 3.7567 0.0683 sec/batch
# Nearest to over:years, zero, in, four, and, mbit, is, two
# Nearest to only:however, for, and, direct, s, but, to, following
# Nearest to also:is, and, of, the, in, other, for, are
# Nearest to not:any, be, still, a, the, which, that, is
# Nearest to which:the, a, from, of, as, in, with, is
# Nearest to more:are, most, less, apart, but, than, there, standard
# Nearest to there:are, of, is, least, living, for, families, more
# Nearest to the:a, of, and, in, for, to, which, is
# Nearest to powers:superhuman, marvel, withhold, pacifists, indirectly, protectorates, spider, crisis
# Nearest to accepted:mostar, although, silenced, revolver, concerned, locations, fantasyland, chemists
# Nearest to arts:martial, qigong, jujutsu, academy, techniques, crafts, art, randori
# Nearest to instance:for, memorized, aneristic, ruins, dwarfed, paraphrased, arbitrarily, simplified
# Nearest to cost:buckinghamshire, costs, wage, eitc, ride, presidencia, binitarianism, devises
# Nearest to ice:swedes, glaciers, hockey, debris, frozen, warming, khanty, barrington
# Nearest to pressure:pressures, spl, vapor, aborted, antonescu, exchanger, president, anson
# Nearest to assembly:aznavour, legislative, lcms, assembl, ephemera, parliamentary, representatives, referendum
# Epoch 12/12 Iteration: 51100 Avg. Training loss: 3.7266 0.0686 sec/batch
# Epoch 12/12 Iteration: 51200 Avg. Training loss: 3.7669 0.0687 sec/batch
# Epoch 12/12 Iteration: 51300 Avg. Training loss: 3.7685 0.0683 sec/batch
# Epoch 12/12 Iteration: 51400 Avg. Training loss: 3.7296 0.0677 sec/batch
# Epoch 12/12 Iteration: 51500 Avg. Training loss: 3.7376 0.0675 sec/batch
# Epoch 12/12 Iteration: 51600 Avg. Training loss: 3.7134 0.0678 sec/batch
# Epoch 12/12 Iteration: 51700 Avg. Training loss: 3.7421 0.0685 sec/batch
# Epoch 12/12 Iteration: 51800 Avg. Training loss: 3.7469 0.0681 sec/batch
# Epoch 12/12 Iteration: 51900 Avg. Training loss: 3.7854 0.0694 sec/batch
# Epoch 12/12 Iteration: 52000 Avg. Training loss: 3.7039 0.0683 sec/batch
# Nearest to over:years, in, mbit, is, four, and, zero, for
# Nearest to only:for, to, and, however, the, but, is, direct
# Nearest to also:is, and, the, of, in, a, for, are
# Nearest to not:any, be, a, is, that, to, still, the
# Nearest to which:the, a, from, as, of, is, in, an
# Nearest to more:most, are, less, but, apart, than, with, there
# Nearest to there:are, of, is, least, living, for, many, and
# Nearest to the:a, of, and, for, to, in, which, as
# Nearest to powers:superhuman, marvel, pacifists, withhold, costumed, spider, indirectly, crisis
# Nearest to accepted:mostar, although, silenced, been, concerned, locations, revolver, questioned
# Nearest to arts:martial, qigong, academy, jujutsu, crafts, randori, techniques, jutsu
# Nearest to instance:memorized, aneristic, for, dwarfed, ruins, affectionately, do, simplified
# Nearest to cost:buckinghamshire, costs, wage, ride, binitarianism, eitc, medusa, devises
# Nearest to ice:glaciers, debris, swedes, warming, hockey, frozen, khanty, barrington
# Nearest to pressure:pressures, vapor, spl, exchanger, aborted, stockpile, president, antonescu
# Nearest to assembly:legislative, aznavour, assembl, lcms, parliamentary, elected, unicameral, representatives
# Epoch 12/12 Iteration: 52100 Avg. Training loss: 3.7004 0.0697 sec/batch
# Epoch 12/12 Iteration: 52200 Avg. Training loss: 3.7088 0.0678 sec/batch
# Epoch 12/12 Iteration: 52300 Avg. Training loss: 3.6772 0.0683 sec/batch
# Epoch 12/12 Iteration: 52400 Avg. Training loss: 3.7258 0.0689 sec/batch
# Epoch 12/12 Iteration: 52500 Avg. Training loss: 3.7494 0.0680 sec/batch
# Epoch 12/12 Iteration: 52600 Avg. Training loss: 3.7487 0.0686 sec/batch
# Epoch 12/12 Iteration: 52700 Avg. Training loss: 3.7399 0.0684 sec/batch
# Epoch 12/12 Iteration: 52800 Avg. Training loss: 3.7728 0.0687 sec/batch
# Epoch 12/12 Iteration: 52900 Avg. Training loss: 3.7791 0.0686 sec/batch
# Epoch 12/12 Iteration: 53000 Avg. Training loss: 3.7543 0.0689 sec/batch
# Nearest to over:years, is, mbit, four, zero, in, for, two
# Nearest to only:however, direct, for, the, is, but, and, to
# Nearest to also:is, the, and, of, in, a, are, other
# Nearest to not:any, be, a, many, all, still, is, it
# Nearest to which:the, a, from, an, in, of, on, as
# Nearest to more:less, are, most, but, apart, there, all, with
# Nearest to there:are, of, is, least, for, many, living, and
# Nearest to the:a, of, and, for, in, to, which, is
# Nearest to powers:superhuman, marvel, indirectly, pacifists, withhold, crisis, spider, costumed
# Nearest to accepted:mostar, although, midwifery, been, concerned, silenced, revolver, rather
# Nearest to arts:academy, qigong, crafts, martial, jujutsu, art, randori, jutsu
# Nearest to instance:memorized, for, ruins, aneristic, simplified, dwarfed, do, shifted
# Nearest to cost:buckinghamshire, costs, eitc, ride, medusa, binitarianism, wage, lidar
# Nearest to ice:frozen, debris, glaciers, hockey, warming, swedes, derbyshire, barrington
# Nearest to pressure:pressures, vapor, spl, exchanger, aborted, antonescu, silicon, president
# Nearest to assembly:aznavour, assembl, legislative, lcms, elected, parliamentary, platters, representatives
# Epoch 12/12 Iteration: 53100 Avg. Training loss: 3.7276 0.0689 sec/batch
# Epoch 12/12 Iteration: 53200 Avg. Training loss: 3.7696 0.0683 sec/batch
# Epoch 12/12 Iteration: 53300 Avg. Training loss: 3.7618 0.0684 sec/batch
# Epoch 12/12 Iteration: 53400 Avg. Training loss: 3.7180 0.0686 sec/batch
# Epoch 12/12 Iteration: 53500 Avg. Training loss: 3.7855 0.0681 sec/batch
# Epoch 12/12 Iteration: 53600 Avg. Training loss: 3.7836 0.0682 sec/batch
# Epoch 12/12 Iteration: 53700 Avg. Training loss: 3.7093 0.0672 sec/batch
# Epoch 12/12 Iteration: 53800 Avg. Training loss: 3.7728 0.0682 sec/batch
# Epoch 12/12 Iteration: 53900 Avg. Training loss: 3.7951 0.0690 sec/batch
# Epoch 12/12 Iteration: 54000 Avg. Training loss: 3.7643 0.0678 sec/batch
# Nearest to over:years, four, is, the, for, and, mbit, zero
# Nearest to only:however, direct, and, for, is, s, following, but
# Nearest to also:the, is, and, of, in, which, a, an
# Nearest to not:any, be, still, it, the, all, to, a
# Nearest to which:the, a, from, also, an, as, in, of
# Nearest to more:most, less, are, apart, but, than, there, makes
# Nearest to there:are, of, is, least, for, living, more, and
# Nearest to the:of, a, and, in, for, to, which, as
# Nearest to powers:superhuman, marvel, withhold, pacifists, indirectly, prerogatives, exercised, crisis
# Nearest to accepted:mostar, questioned, concerned, revolver, although, been, silenced, rather
# Nearest to arts:academy, qigong, crafts, jujutsu, martial, techniques, art, randori
# Nearest to instance:for, memorized, ruins, dwarfed, burdens, aneristic, paraphrased, do
# Nearest to cost:buckinghamshire, costs, binitarianism, ride, eitc, wage, lidar, medusa
# Nearest to ice:glaciers, frozen, debris, warming, hockey, khanty, swedes, remaining
# Nearest to pressure:pressures, vapor, spl, exchanger, aborted, antonescu, president, motu
# Nearest to assembly:aznavour, assembl, legislative, lcms, parliamentary, ephemera, elected, platters
# Epoch 12/12 Iteration: 54100 Avg. Training loss: 3.7086 0.0698 sec/batch
# Epoch 12/12 Iteration: 54200 Avg. Training loss: 3.7069 0.0673 sec/batch
# Epoch 12/12 Iteration: 54300 Avg. Training loss: 3.7096 0.0680 sec/batch
# Epoch 12/12 Iteration: 54400 Avg. Training loss: 3.8022 0.0678 sec/batch
# Epoch 12/12 Iteration: 54500 Avg. Training loss: 3.7632 0.0680 sec/batch
# Epoch 12/12 Iteration: 54600 Avg. Training loss: 3.8424 0.0680 sec/batch
# Epoch 12/12 Iteration: 54700 Avg. Training loss: 3.7837 0.0693 sec/batch
# Epoch 12/12 Iteration: 54800 Avg. Training loss: 3.7369 0.0679 sec/batch
# Epoch 12/12 Iteration: 54900 Avg. Training loss: 3.7184 0.0683 sec/batch
# Epoch 12/12 Iteration: 55000 Avg. Training loss: 3.7355 0.0681 sec/batch
# Nearest to over:four, years, is, and, mbit, distributed, in, under
# Nearest to only:however, direct, s, and, following, for, to, that
# Nearest to also:is, and, the, other, which, of, are, in
# Nearest to not:any, be, still, is, to, that, it, does
# Nearest to which:a, the, from, in, as, also, an, of
# Nearest to more:less, most, are, but, apart, than, makes, there
# Nearest to there:are, of, is, least, and, for, living, the
# Nearest to the:a, of, and, for, in, to, which, as
# Nearest to powers:superhuman, marvel, indirectly, pacifists, withhold, costumed, exercised, spider
# Nearest to accepted:mostar, revolver, although, questioned, silenced, concerned, midwifery, been
# Nearest to arts:academy, qigong, jujutsu, martial, crafts, techniques, art, randori
# Nearest to instance:for, ruins, memorized, aneristic, simplified, do, dwarfed, paraphrased
# Nearest to cost:buckinghamshire, costs, binitarianism, eitc, ride, lidar, solicited, michelangelo
# Nearest to ice:frozen, warming, swedes, hockey, glaciers, debris, khanty, barrington
# Nearest to pressure:pressures, vapor, spl, exchanger, aborted, antonescu, stockpile, anson
# Nearest to assembly:aznavour, assembl, legislative, lcms, ephemera, elected, platters, parliamentary
# Epoch 12/12 Iteration: 55100 Avg. Training loss: 3.7059 0.0700 sec/batch
# Epoch 12/12 Iteration: 55200 Avg. Training loss: 3.7411 0.0682 sec/batch
# Epoch 12/12 Iteration: 55300 Avg. Training loss: 3.7489 0.0670 sec/batch
# Epoch 12/12 Iteration: 55400 Avg. Training loss: 3.7122 0.0681 sec/batch
# Epoch 12/12 Iteration: 55500 Avg. Training loss: 3.7744 0.0681 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
5
# Out:
# 5

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %%
import pickle
with open('word_embeddings.pkl', 'wb') as f:
    p = pickle.Pickler(f)
    p.dump([vocab_to_int, embed_mat])

# %%
vocab_to_int
# Out:
# {'the': 0,
#  'of': 1,
#  'and': 2,
#  'one': 3,
#  'in': 4,
#  'a': 5,
#  'to': 6,
#  'zero': 7,
#  'nine': 8,
#  'two': 9,
#  'is': 10,
#  'as': 11,
#  'eight': 12,
#  'for': 13,
#  's': 14,
#  'five': 15,
#  'three': 16,
#  'was': 17,
#  'by': 18,
#  'that': 19,
#  'four': 20,
#  'six': 21,
#  'seven': 22,
#  'with': 23,
#  'on': 24,
#  'are': 25,
#  'it': 26,
#  'from': 27,
#  'or': 28,
#  'his': 29,
#  'an': 30,
#  'be': 31,
#  'this': 32,
#  'which': 33,
#  'at': 34,
#  'he': 35,
#  'also': 36,
#  'not': 37,
#  'have': 38,
#  'were': 39,
#  'has': 40,
#  'but': 41,
#  'other': 42,
#  'their': 43,
#  'its': 44,
#  'first': 45,
#  'they': 46,
#  'some': 47,
#  'had': 48,
#  'all': 49,
#  'more': 50,
#  'most': 51,
#  'can': 52,
#  'been': 53,
#  'such': 54,
#  'many': 55,
#  'who': 56,
#  'new': 57,
#  'used': 58,
#  'there': 59,
#  'after': 60,
#  'when': 61,
#  'into': 62,
#  'american': 63,
#  'time': 64,
#  'these': 65,
#  'only': 66,
#  'see': 67,
#  'may': 68,
#  'than': 69,
#  'world': 70,
#  'i': 71,
#  'b': 72,
#  'would': 73,
#  'd': 74,
#  'no': 75,
#  'however': 76,
#  'between': 77,
#  'about': 78,
#  'over': 79,
#  'years': 80,
#  'states': 81,
#  'people': 82,
#  'war': 83,
#  'during': 84,
#  'united': 85,
#  'known': 86,
#  'if': 87,
#  'called': 88,
#  'use': 89,
#  'th': 90,
#  'system': 91,
#  'often': 92,
#  'state': 93,
#  'so': 94,
#  'history': 95,
#  'will': 96,
#  'up': 97,
#  'while': 98,
#  'where': 99,
#  'city': 100,
#  'being': 101,
#  'english': 102,
#  'then': 103,
#  'any': 104,
#  'both': 105,
#  'under': 106,
#  'out': 107,
#  'made': 108,
#  'well': 109,
#  'her': 110,
#  'e': 111,
#  'number': 112,
#  'government': 113,
#  'them': 114,
#  'm': 115,
#  'later': 116,
#  'since': 117,
#  'him': 118,
#  'part': 119,
#  'name': 120,
#  'c': 121,
#  'century': 122,
#  'through': 123,
#  'because': 124,
#  'x': 125,
#  'university': 126,
#  'early': 127,
#  'life': 128,
#  'british': 129,
#  'year': 130,
#  'like': 131,
#  'same': 132,
#  'including': 133,
#  'became': 134,
#  'example': 135,
#  'day': 136,
#  'each': 137,
#  'even': 138,
#  'work': 139,
#  'language': 140,
#  'although': 141,
#  'several': 142,
#  'form': 143,
#  'john': 144,
#  'u': 145,
#  'national': 146,
#  'very': 147,
#  'much': 148,
#  'g': 149,
#  'french': 150,
#  'before': 151,
#  'general': 152,
#  'what': 153,
#  't': 154,
#  'against': 155,
#  'n': 156,
#  'high': 157,
#  'links': 158,
#  'could': 159,
#  'based': 160,
#  'those': 161,
#  'now': 162,
#  'second': 163,
#  'de': 164,
#  'music': 165,
#  'another': 166,
#  'large': 167,
#  'she': 168,
#  'f': 169,
#  'external': 170,
#  'german': 171,
#  'different': 172,
#  'modern': 173,
#  'great': 174,
#  'do': 175,
#  'common': 176,
#  'set': 177,
#  'list': 178,
#  'south': 179,
#  'series': 180,
#  'major': 181,
#  'game': 182,
#  'power': 183,
#  'long': 184,
#  'country': 185,
#  'king': 186,
#  'law': 187,
#  'group': 188,
#  'film': 189,
#  'still': 190,
#  'until': 191,
#  'north': 192,
#  'international': 193,
#  'term': 194,
#  'we': 195,
#  'end': 196,
#  'book': 197,
#  'found': 198,
#  'own': 199,
#  'political': 200,
#  'party': 201,
#  'order': 202,
#  'usually': 203,
#  'president': 204,
#  'church': 205,
#  'you': 206,
#  'death': 207,
#  'theory': 208,
#  'area': 209,
#  'around': 210,
#  'include': 211,
#  'god': 212,
#  'ii': 213,
#  'way': 214,
#  'did': 215,
#  'military': 216,
#  'population': 217,
#  'using': 218,
#  'though': 219,
#  'small': 220,
#  'following': 221,
#  'within': 222,
#  'non': 223,
#  'human': 224,
#  'left': 225,
#  'main': 226,
#  'among': 227,
#  'point': 228,
#  'r': 229,
#  'due': 230,
#  'p': 231,
#  'considered': 232,
#  'public': 233,
#  'popular': 234,
#  'computer': 235,
#  'west': 236,
#  'family': 237,
#  'east': 238,
#  'information': 239,
#  'important': 240,
#  'european': 241,
#  'man': 242,
#  'sometimes': 243,
#  'right': 244,
#  'old': 245,
#  'free': 246,
#  'word': 247,
#  'without': 248,
#  'last': 249,
#  'us': 250,
#  'members': 251,
#  'given': 252,
#  'times': 253,
#  'roman': 254,
#  'make': 255,
#  'h': 256,
#  'age': 257,
#  'place': 258,
#  'l': 259,
#  'thus': 260,
#  'science': 261,
#  'case': 262,
#  'become': 263,
#  'systems': 264,
#  'union': 265,
#  'born': 266,
#  'york': 267,
#  'line': 268,
#  'countries': 269,
#  'does': 270,
#  'isbn': 271,
#  'st': 272,
#  'control': 273,
#  'various': 274,
#  'others': 275,
#  'house': 276,
#  'article': 277,
#  'island': 278,
#  'should': 279,
#  'led': 280,
#  'back': 281,
#  'period': 282,
#  'player': 283,
#  'europe': 284,
#  'languages': 285,
#  'central': 286,
#  'water': 287,
#  'few': 288,
#  'western': 289,
#  'home': 290,
#  'began': 291,
#  'generally': 292,
#  'less': 293,
#  'k': 294,
#  'similar': 295,
#  'written': 296,
#  'original': 297,
#  'best': 298,
#  'must': 299,
#  'according': 300,
#  'school': 301,
#  'france': 302,
#  'air': 303,
#  'single': 304,
#  'force': 305,
#  'v': 306,
#  'land': 307,
#  'groups': 308,
#  'down': 309,
#  'how': 310,
#  'works': 311,
#  'development': 312,
#  'official': 313,
#  'support': 314,
#  'england': 315,
#  'j': 316,
#  'rather': 317,
#  'data': 318,
#  'space': 319,
#  'greek': 320,
#  'km': 321,
#  'named': 322,
#  'germany': 323,
#  'just': 324,
#  'games': 325,
#  'said': 326,
#  'version': 327,
#  'late': 328,
#  'earth': 329,
#  'company': 330,
#  'every': 331,
#  'economic': 332,
#  'short': 333,
#  'published': 334,
#  'black': 335,
#  'army': 336,
#  'off': 337,
#  'london': 338,
#  'million': 339,
#  'body': 340,
#  'field': 341,
#  'christian': 342,
#  'either': 343,
#  'social': 344,
#  'empire': 345,
#  'o': 346,
#  'developed': 347,
#  'standard': 348,
#  'court': 349,
#  'service': 350,
#  'kingdom': 351,
#  'along': 352,
#  'college': 353,
#  'republic': 354,
#  'sea': 355,
#  'america': 356,
#  'today': 357,
#  'result': 358,
#  'held': 359,
#  'team': 360,
#  'light': 361,
#  'means': 362,
#  'never': 363,
#  'especially': 364,
#  'third': 365,
#  'further': 366,
#  'character': 367,
#  'forces': 368,
#  'take': 369,
#  'men': 370,
#  'society': 371,
#  'show': 372,
#  'open': 373,
#  'possible': 374,
#  'fact': 375,
#  'battle': 376,
#  'took': 377,
#  'former': 378,
#  'books': 379,
#  'soviet': 380,
#  'river': 381,
#  'children': 382,
#  'having': 383,
#  'good': 384,
#  'local': 385,
#  'current': 386,
#  'son': 387,
#  'process': 388,
#  'natural': 389,
#  'present': 390,
#  'himself': 391,
#  'islands': 392,
#  'total': 393,
#  'near': 394,
#  'white': 395,
#  'days': 396,
#  'person': 397,
#  'itself': 398,
#  'seen': 399,
#  'culture': 400,
#  'little': 401,
#  'above': 402,
#  'software': 403,
#  'largest': 404,
#  'words': 405,
#  'upon': 406,
#  'level': 407,
#  'father': 408,
#  'created': 409,
#  'side': 410,
#  'red': 411,
#  'references': 412,
#  'press': 413,
#  'full': 414,
#  'region': 415,
#  'almost': 416,
#  'image': 417,
#  'al': 418,
#  'famous': 419,
#  'play': 420,
#  'came': 421,
#  'role': 422,
#  'once': 423,
#  'certain': 424,
#  'league': 425,
#  'jewish': 426,
#  'james': 427,
#  'january': 428,
#  'site': 429,
#  'again': 430,
#  'numbers': 431,
#  'art': 432,
#  'member': 433,
#  'areas': 434,
#  'movement': 435,
#  'religious': 436,
#  'type': 437,
#  'march': 438,
#  'community': 439,
#  'story': 440,
#  'played': 441,
#  'production': 442,
#  'released': 443,
#  'center': 444,
#  'rights': 445,
#  'real': 446,
#  'related': 447,
#  'foreign': 448,
#  'low': 449,
#  'ancient': 450,
#  'terms': 451,
#  'view': 452,
#  'source': 453,
#  'act': 454,
#  'minister': 455,
#  'change': 456,
#  'energy': 457,
#  'produced': 458,
#  'research': 459,
#  'actor': 460,
#  'making': 461,
#  'civil': 462,
#  'december': 463,
#  'women': 464,
#  'special': 465,
#  'style': 466,
#  'william': 467,
#  'design': 468,
#  'japanese': 469,
#  'available': 470,
#  'chinese': 471,
#  'forms': 472,
#  'canada': 473,
#  'northern': 474,
#  'died': 475,
#  'class': 476,
#  'living': 477,
#  'next': 478,
#  'particular': 479,
#  'program': 480,
#  'council': 481,
#  'television': 482,
#  'head': 483,
#  'david': 484,
#  'china': 485,
#  'middle': 486,
#  'established': 487,
#  'hand': 488,
#  'bc': 489,
#  'far': 490,
#  'july': 491,
#  'function': 492,
#  'position': 493,
#  'y': 494,
#  'built': 495,
#  'george': 496,
#  'band': 497,
#  'together': 498,
#  'w': 499,
#  'latin': 500,
#  'thought': 501,
#  'eastern': 502,
#  'charles': 503,
#  'parts': 504,
#  'instead': 505,
#  'study': 506,
#  'might': 507,
#  'india': 508,
#  'code': 509,
#  'included': 510,
#  'meaning': 511,
#  'trade': 512,
#  'per': 513,
#  'june': 514,
#  'least': 515,
#  'half': 516,
#  'model': 517,
#  'economy': 518,
#  'prime': 519,
#  'traditional': 520,
#  'always': 521,
#  'capital': 522,
#  'range': 523,
#  'november': 524,
#  'emperor': 525,
#  'young': 526,
#  'anti': 527,
#  'final': 528,
#  'text': 529,
#  'players': 530,
#  'uk': 531,
#  'april': 532,
#  'run': 533,
#  'september': 534,
#  'addition': 535,
#  'radio': 536,
#  'live': 537,
#  'august': 538,
#  'taken': 539,
#  'note': 540,
#  'italian': 541,
#  'lost': 542,
#  'nature': 543,
#  'project': 544,
#  'technology': 545,
#  'spanish': 546,
#  'october': 547,
#  'recent': 548,
#  'rate': 549,
#  'won': 550,
#  'true': 551,
#  'value': 552,
#  'uses': 553,
#  'russian': 554,
#  'est': 555,
#  'wrote': 556,
#  'effect': 557,
#  'album': 558,
#  'southern': 559,
#  'africa': 560,
#  'whose': 561,
#  'top': 562,
#  'historical': 563,
#  'australia': 564,
#  'catholic': 565,
#  'particularly': 566,
#  'self': 567,
#  'structure': 568,
#  'record': 569,
#  'evidence': 570,
#  'rule': 571,
#  'themselves': 572,
#  'influence': 573,
#  'cases': 574,
#  'subject': 575,
#  'referred': 576,
#  'continued': 577,
#  'nations': 578,
#  'below': 579,
#  'rock': 580,
#  'japan': 581,
#  'com': 582,
#  'song': 583,
#  'throughout': 584,
#  'names': 585,
#  'female': 586,
#  'title': 587,
#  'therefore': 588,
#  'our': 589,
#  'office': 590,
#  'star': 591,
#  'paul': 592,
#  'too': 593,
#  'cities': 594,
#  'february': 595,
#  'independent': 596,
#  'author': 597,
#  'problem': 598,
#  'species': 599,
#  'education': 600,
#  'done': 601,
#  'philosophy': 602,
#  'come': 603,
#  'higher': 604,
#  'originally': 605,
#  'market': 606,
#  'town': 607,
#  'my': 608,
#  'season': 609,
#  'love': 610,
#  'strong': 611,
#  'israel': 612,
#  'irish': 613,
#  'writer': 614,
#  'films': 615,
#  'elements': 616,
#  'robert': 617,
#  'whether': 618,
#  'despite': 619,
#  'eventually': 620,
#  'here': 621,
#  'football': 622,
#  'action': 623,
#  'internet': 624,
#  'individual': 625,
#  'sound': 626,
#  'network': 627,
#  'described': 628,
#  'practice': 629,
#  'characters': 630,
#  're': 631,
#  'royal': 632,
#  'la': 633,
#  'events': 634,
#  'formed': 635,
#  'commonly': 636,
#  'base': 637,
#  'received': 638,
#  'african': 639,
#  'problems': 640,
#  'food': 641,
#  'jews': 642,
#  'able': 643,
#  'male': 644,
#  'typically': 645,
#  'mass': 646,
#  'complex': 647,
#  'lower': 648,
#  'includes': 649,
#  'outside': 650,
#  'legal': 651,
#  'complete': 652,
#  'significant': 653,
#  'parliament': 654,
#  'actually': 655,
#  'business': 656,
#  'fiction': 657,
#  'physical': 658,
#  'followed': 659,
#  'deaths': 660,
#  'key': 661,
#  'leader': 662,
#  'widely': 663,
#  'page': 664,
#  'basic': 665,
#  'types': 666,
#  'henry': 667,
#  'elected': 668,
#  'beginning': 669,
#  'fire': 670,
#  'building': 671,
#  'independence': 672,
#  'went': 673,
#  'movie': 674,
#  'aircraft': 675,
#  'ever': 676,
#  'canadian': 677,
#  'material': 678,
#  'births': 679,
#  'video': 680,
#  'news': 681,
#  'future': 682,
#  'scientific': 683,
#  'simply': 684,
#  'go': 685,
#  'defined': 686,
#  'laws': 687,
#  'get': 688,
#  'close': 689,
#  'industry': 690,
#  'specific': 691,
#  'examples': 692,
#  'believe': 693,
#  'services': 694,
#  'idea': 695,
#  'method': 696,
#  'introduced': 697,
#  'points': 698,
#  'return': 699,
#  'cause': 700,
#  'indian': 701,
#  'britain': 702,
#  'features': 703,
#  'majority': 704,
#  'size': 705,
#  'post': 706,
#  'lead': 707,
#  'organization': 708,
#  'cannot': 709,
#  'designed': 710,
#  'ireland': 711,
#  'cross': 712,
#  'classical': 713,
#  'personal': 714,
#  'writing': 715,
#  'concept': 716,
#  'associated': 717,
#  'required': 718,
#  'soon': 719,
#  'changes': 720,
#  'california': 721,
#  'located': 722,
#  'sense': 723,
#  'believed': 724,
#  'away': 725,
#  'started': 726,
#  'co': 727,
#  'religion': 728,
#  'mother': 729,
#  'county': 730,
#  'rules': 731,
#  'studies': 732,
#  'yet': 733,
#  'find': 734,
#  'knowledge': 735,
#  'put': 736,
#  'founded': 737,
#  'policy': 738,
#  'currently': 739,
#  'provide': 740,
#  'working': 741,
#  'media': 742,
#  'election': 743,
#  'australian': 744,
#  'me': 745,
#  'thomas': 746,
#  'allowed': 747,
#  'russia': 748,
#  'earlier': 749,
#  'greater': 750,
#  'limited': 751,
#  'object': 752,
#  'brought': 753,
#  'online': 754,
#  'association': 755,
#  'lord': 756,
#  'mostly': 757,
#  'blue': 758,
#  'constitution': 759,
#  'across': 760,
#  'added': 761,
#  'interest': 762,
#  'things': 763,
#  'relations': 764,
#  'speed': 765,
#  'federal': 766,
#  'singer': 767,
#  'effects': 768,
#  'growth': 769,
#  'sources': 770,
#  'your': 771,
#  'remains': 772,
#  'z': 773,
#  'probably': 774,
#  'gave': 775,
#  'simple': 776,
#  'attack': 777,
#  'longer': 778,
#  'reference': 779,
#  'saint': 780,
#  'success': 781,
#  'killed': 782,
#  'past': 783,
#  'career': 784,
#  'need': 785,
#  'park': 786,
#  'definition': 787,
#  'say': 788,
#  'etc': 789,
#  'give': 790,
#  'peace': 791,
#  'chief': 792,
#  'stories': 793,
#  'security': 794,
#  'wide': 795,
#  'ball': 796,
#  'saw': 797,
#  'machine': 798,
#  'better': 799,
#  'cell': 800,
#  'leading': 801,
#  'becomes': 802,
#  'spain': 803,
#  'larger': 804,
#  'products': 805,
#  'parties': 806,
#  'night': 807,
#  'remained': 808,
#  'prize': 809,
#  'months': 810,
#  'website': 811,
#  'big': 812,
#  'cultural': 813,
#  'money': 814,
#  'help': 815,
#  'territory': 816,
#  'private': 817,
#  'moved': 818,
#  'letter': 819,
#  'wife': 820,
#  'politics': 821,
#  'lines': 822,
#  'largely': 823,
#  'contains': 824,
#  'companies': 825,
#  'lake': 826,
#  'perhaps': 827,
#  'green': 828,
#  'already': 829,
#  'dead': 830,
#  'iii': 831,
#  'library': 832,
#  'separate': 833,
#  'refer': 834,
#  'makes': 835,
#  'appeared': 836,
#  'dutch': 837,
#  'holy': 838,
#  'era': 839,
#  'novel': 840,
#  'successful': 841,
#  'italy': 842,
#  'letters': 843,
#  'results': 844,
#  'matter': 845,
#  'produce': 846,
#  'origin': 847,
#  'claim': 848,
#  'whole': 849,
#  'directly': 850,
#  'attempt': 851,
#  'actress': 852,
#  'surface': 853,
#  'revolution': 854,
#  'highly': 855,
#  'caused': 856,
#  'status': 857,
#  'musical': 858,
#  'richard': 859,
#  'commercial': 860,
#  'division': 861,
#  'color': 862,
#  'health': 863,
#  'coast': 864,
#  'release': 865,
#  'latter': 866,
#  'authority': 867,
#  'treaty': 868,
#  'turn': 869,
#  'michael': 870,
#  'nation': 871,
#  'direct': 872,
#  'asia': 873,
#  'edition': 874,
#  'programming': 875,
#  'playing': 876,
#  'date': 877,
#  'mary': 878,
#  'native': 879,
#  'whom': 880,
#  'married': 881,
#  'towards': 882,
#  'issues': 883,
#  'double': 884,
#  'primary': 885,
#  'basis': 886,
#  'allow': 887,
#  'enough': 888,
#  'memory': 889,
#  'reason': 890,
#  'web': 891,
#  'exist': 892,
#  'provided': 893,
#  'oil': 894,
#  'course': 895,
#  'functions': 896,
#  'alexander': 897,
#  'analysis': 898,
#  'chemical': 899,
#  'mid': 900,
#  'replaced': 901,
#  'queen': 902,
#  'claims': 903,
#  'tv': 904,
#  'sun': 905,
#  'literature': 906,
#  'metal': 907,
#  'amount': 908,
#  'divided': 909,
#  'blood': 910,
#  'likely': 911,
#  'access': 912,
#  'average': 913,
#  'length': 914,
#  'smaller': 915,
#  'medical': 916,
#  'property': 917,
#  'students': 918,
#  'degree': 919,
#  'elections': 920,
#  'club': 921,
#  'claimed': 922,
#  'performance': 923,
#  'director': 924,
#  'digital': 925,
#  'front': 926,
#  'museum': 927,
#  'difficult': 928,
#  'tradition': 929,
#  'nearly': 930,
#  'schools': 931,
#  'washington': 932,
#  'gas': 933,
#  'jesus': 934,
#  'map': 935,
#  'louis': 936,
#  'rome': 937,
#  'unit': 938,
#  'baseball': 939,
#  'mind': 940,
#  'peter': 941,
#  'mark': 942,
#  'collection': 943,
#  'product': 944,
#  'congress': 945,
#  'programs': 946,
#  'changed': 947,
#  'ideas': 948,
#  'moon': 949,
#  'entire': 950,
#  'user': 951,
#  'ground': 952,
#  'records': 953,
#  'frequently': 954,
#  'increase': 955,
#  'highest': 956,
#  'sent': 957,
#  'finally': 958,
#  'board': 959,
#  'don': 960,
#  'notable': 961,
#  'read': 962,
#  'methods': 963,
#  'recently': 964,
#  'bit': 965,
#  'involved': 966,
#  'variety': 967,
#  'call': 968,
#  'democratic': 969,
#  'ten': 970,
#  'served': 971,
#  'minor': 972,
#  'hard': 973,
#  'birth': 974,
#  'objects': 975,
#  'nuclear': 976,
#  'increased': 977,
#  'section': 978,
#  'street': 979,
#  'windows': 980,
#  'relatively': 981,
#  'car': 982,
#  'move': 983,
#  'create': 984,
#  'returned': 985,
#  'bank': 986,
#  'conditions': 987,
#  'operation': 988,
#  'adopted': 989,
#  'relationship': 990,
#  'christ': 991,
#  'hall': 992,
#  'appear': 993,
#  'rest': 994,
#  'child': 995,
#  'element': 996,
#  'appears': 997,
#  'takes': 998,
#  'fall': 999,
#  ...}

# %%
def word_difference(a,b):
    word_a = embed_mat[vocab_to_int[a],:]
    word_b = embed_mat[vocab_to_int[b],:]
    return word_b - word_a

# %%
kq = word_difference('king', 'queen')

# %%
pp = word_difference('prince', 'princess')

# %%
def cosine_similarity(a,b):
    return np.dot(a,b) / np.sqrt(np.sum(np.square(a)) + np.sum(np.square(b)))

# %%
cosine_similarity(kq,pp)
# Out:
# 0.0015999459

# %%
def analogy(a,b,A,B=None):
    if B is None:
        best_word = -1
        best_diff = -1
        ab = word_difference(a,b)
        idx_b = vocab_to_int[b]
        word_A = embed_mat[vocab_to_int[A],:]
        for i in int_to_vocab.keys():
            word_B = embed_mat[i,:]
            AB = cosine_similarity(ab, word_B - word_A)
            if AB > best_diff and i != idx_b:
                best_diff = AB
                best_word = i
        return (int_to_vocab[best_word], best_diff)
    else:
        ab = word_difference(a,b)
        AB = word_difference(A,B)
        return cosine_similarity(ab,AB)

# %%
def analogy(a,b,c):
    input_idxs = tuple([vocab_to_int[i] for i in [a,b,c]])
    diff = embed_mat[vocab_to_int[b],:] - embed_mat[vocab_to_int[a],:]
    d_embed = embed_mat[vocab_to_int[c],:] + diff
    
    closest_word = -1
    closest_error = np.inf
    
    for i in int_to_vocab.keys():
        error = np.sqrt(np.sum(np.square(embed_mat[i,:] - d_embed)))
        if error < closest_error and i not in input_idxs:
            closest_word = i
            closest_error = error
    
    return (int_to_vocab[closest_word], closest_error)

# %%
analogy('man', 'woman', 'men')
# Out:
# ('women', 1.4388856)

# %%
analogy('better','best', 'worse')
# Out:
# ('satara', 1.6486371)

# %%
analogy('his','her','he')
# Out:
# ('she', 1.2619072)

# %%
analogy('east','west','north')
# Out:
# ('south', 1.3838494)

# %%
analogy('force', 'forces', 'book')
# Out:
# ('vigilance', 1.5039809)

# %%
analogy('man','woman','he')
# Out:
# ('salaino', 1.5708857)

# %%
analogy('france','paris','spain')
# Out:
# ('bogot', 1.4455863)

# %%
analogy('france','french','japan')
# Out:
# ('japanese', 1.3163509)

# %%
analogy('japan','japanese','china')
# Out:
# ('han', 1.4620105)

# %%
analogy('france','french','canada')
# Out:
# ('canadian', 1.4493972)

# %%
analogy('france','french','spain')
# Out:
# ('morons', 1.4011776)

# %%
analogy('')
# Out:
# ('siqueiros', 1.7109681)
